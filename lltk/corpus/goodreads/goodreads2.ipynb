# %%
import sys; sys.path.insert(0,'/Users/ryan/github/yapmap')
import os,sys; sys.path.insert(0,os.path.abspath('../../..'))
from lltk import *
# !open {log.fn}

# %%
t=Text(get_idx(), title='Emma', author='Jane Austen')

# %%
with log:
    C=Corpus('goodreads')
    tg = C.text_from(t)
    tg
# Out:
# [18:13:11] lltk.corpus.corpus.Corpus( <- id = goodreads )
# [18:13:11] lltk.corpus.utils.load_corpus( <- id = goodreads )
# [18:13:11] lltk.corpus.utils.load_corpus( Importing corpus class "Goodreads" from /Users/ryan/github/lltk/lltk/corpus/goodreads/goodreads.py )
# [18:13:11] lltk.corpus.corpus.__init__( Goodreads(goodreads) )
# [18:13:11] lltk.corpus.utils.load_corpus( -> GoodreadsCorpus(goodreads) )
# [18:13:11] lltk.corpus.corpus.Corpus( -> GoodreadsCorpus(goodreads) )
# [18:13:11] lltk.tools.db.query( ? https://www.goodreads.com/search?utf8=%E2%9C%93&q=Emma+Austen&search_type=books )
# [18:13:12] lltk.tools.db.query( -> <class 'str'> (191592) )
# [18:13:12] goodreads.texts_from_title( parsing html! )
# [18:13:12] goodreads.texts_from_title( {'id': '23395733-emma', 'author_id': '4738.Alexander_McCall_Smith', 'author': 'Alexander McCall Smith', 'title': 'Emma (The Austen Project, #3)', 'year': '2014', 'ratingValue1': 3.14, 'ratingCount1': 12675} )
# ...

# %%
tg.ratingVa
# Out:
# 4.03

# %%
Text('_goodreads/20581275-jane-austen-s-emma').init(remote=True)._meta
# Out:
# ? 20581275-jane-austen-s-emma == 20581275-jane-austen-s-emma ?
# {'id': '20581275-jane-austen-s-emma',
#  '_addr': '_goodreads/20581275-jane-austen-s-emma',
#  '_corpus': 'goodreads',
#  'author': 'Karen Anna Vogel (Goodreads Author)',
#  'author_id': '5182661.Karen_Anna_Vogel',
#  'ratingCount': '16',
#  'ratingCount1': 16,
#  'ratingValue': '4.50',
#  'ratingValue1': 4.5,
#  'title': "Jane Austen's Emma",
#  'year': '2013',
#  'name': ["Jane Austen's Emma", 'Karen Anna Vogel', 'to-read'],
#  'aggregateRating': '4.50',
#  'reviewCount': '0',
#  'bookFormat': 'Kindle Edition',
#  'isbn': 'B00BWBKIOO',
#  'inLanguage': 'English',
#  'reviews': ['Michelle\n\n\n        rated it\n        liked it\n\nJul 06, 2014',
#   'Melanie\n\n\n        rated it\n        liked it\n\nFeb 21, 2014',
#   'carolynn woods\n\n\n        rated it\n        it was amazing\n\nDec 08, 2019',
#   'Pamela Mock\n\n\n        rated it\n        it was amazing\n\nJan 18, 2015',
# ...
