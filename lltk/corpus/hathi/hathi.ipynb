# %%
import sys; sys.path.insert(0,'/Users/ryan/github/yapmap')
import sys; sys.path.insert(0,os.path.abspath('../../..'))
from hathi import *

# %%
with log.quiet:
    C=Corpus('hathi')
    t=Text(title='Ulysses',author='Joyce')

# %%
with log: th=C.text_from(t)
# Out:
# [18:35:46] hathi.query_for_ids( found result on db (48 records) )
# [18:35:46] lltk.corpus.corpus.text( <- id = htrn/000249715, corpus = HathiCorpus(hathi), source = HathiCorpus(hathi) )
# [18:35:46] lltk.corpus.corpus.init_text( <- id = htrn/000249715, corpus = HathiCorpus(hathi), source = HathiCorpus(hathi) )
# [18:35:46] lltk.text.text.__init__( <- id = htrn/000249715, corpus = HathiCorpus(hathi), source = HathiCorpus(hathi) )
# [18:35:46] lltk.text.text.__init__( TextHathi(id = htrn/000249715, corpus = HathiCorpus(hathi), source = HathiCorpus(hathi)) )
# [18:35:46] lltk.text.text.__init__( Loading source? HathiCorpus(hathi) )
# [18:35:46] lltk.corpus.corpus.init_text( -> TextHathi(_hathi/htrn/000249715) )
# [18:35:46] lltk.text.text.cache( TextHathiRecord(_hathi/htrn/000249715) )
# [18:35:46] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htrn/000249715/meta.json )
# [18:35:46] lltk.corpus.corpus.text( -> TextHathiRecord(_hathi/htrn/000249715) )

# %%
th.meta
# Out:
# {'id': 'htrn/000249715',
#  'id__chicago': '00004881',
#  'id__hathi': 'htid/mdp.39015005917375',
#  'id__markmark': 'Joyce,_James.Ulysses',
#  'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#  'id__wikidata': 'Q6511',
#  'access_profile': 'google',
#  'access_rights': 'pd',
#  'ausstage_work_id|P8294__wikidata': '3970',
#  'auth_first__chicago': 'James',
#  'auth_id__chicago': 'A_01848',
#  'auth_last__chicago': 'Joyce',
#  'author': 'Joyce, James, 1882-1941',
#  'author__chicago': 'Joyce, James',
#  'author__markmark': 'Joyce, James Augustine Aloysius',
#  'author__txtlab': 'Joyce,James',
#  'author|P50__wikidata': 'James Joyce|Q6882',
#  'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#  'based_on|P144__wikidata': 'Odyssey|Q35160',
#  'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#  'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#  'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#  'book_id__chicago': '4881',
#  'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#  'bookogs_work_id|P8211__wikidata': '405385',
#  'category': 'English literature',
#  'characters|P674__wikidata': ['Leopold Bloom|Q573988',
#   'Molly Bloom|Q2296791',
#   'Stephen Dedalus|Q543671',
#   'May Goulding Dedalus|Q16910626',
#   'Simon Dedalus|Q7518595',
#   'Milly Bloom|Q6860161',
#   'Buck Mulligan|Q4982905',
#   'Michael Cusack|Q1927217',
#   'George William Russell|Q366070',
#   'William Magee|Q18880357',
#   'Thomas William Lyster|Q1416892',
#   'Joseph Patrick Nannetti|Q1707785',
#   'Richard Irvine Best|Q7326690',
#   'David Sheehy|Q5239704',
#   'John Hooper|Q6239779',
#   'Tisdall Farrell|Q28575591',
#   'Haines|Q28601692',
#   'Martha Clifford|Q28602262',
#   'Garrett Deasy|Q16739979',
#   "C. P. M'Coy|Q28602472",
#   'Corny Kelleher (Ulysses character)|Q16910929',
#   'Jack Power (Ulysses character)|Q16919411',
#   'Martin Cunningham|Q16739992'],
#  'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#  'contributor': ['Joyce, James, 1882-1941',
#   'Melchior, Claus',
#   'Steppe, Wolfhard',
#   'Gabler, Hans Walter, 1938-'],
#  'contributor_ld': [{'id': 'http://www.viaf.org/viaf/44300643',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Joyce, James, 1882-1941'},
#   {'id': 'http://www.viaf.org/viaf/54210018',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Melchior, Claus'},
#   {'id': 'http://www.viaf.org/viaf/14785516',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Steppe, Wolfhard'},
#   {'id': 'http://www.viaf.org/viaf/108429204',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Gabler, Hans Walter, 1938-'}],
#  'copyright_status|P6216__wikidata': ['public domain|Q19652',
#   'public domain|Q19652'],
#  'corpus__markmark': 'MarkMark',
#  'country_of_origin|P495__wikidata': ['France|Q142',
#   'United States of America|Q30',
#   'French Third Republic|Q70802',
#   'United Kingdom of Great Britain and Ireland|Q174193'],
#  'date__txtlab': '1922',
#  'date_b__chicago': '1882',
#  'date_created': 20200209,
#  'date_d__chicago': '1941',
#  'default_page_section': 'body',
#  'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#  'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#  'dob__markmark': '1882.0',
#  'dod__markmark': '1941.0',
#  'education__chicago': 'U Coll Dublin',
#  'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#  'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#  'enumeration_chronology': 'v.3',
#  'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#  'filename__chicago': '00004881.txt',
#  'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the stairhead, bearing a bowl of lather on which a mirror and a razor lay crossed.',
#  'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#  'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#  'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#  'freebase_id|P646__wikidata': '/m/0f3dt',
#  'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#  'gender__chicago': 'M',
#  'gender__markmark': 'M',
#  'gender__txtlab': 'male',
#  'genre': ['document (computer)', 'bibliography', 'fiction'],
#  'genre__chicago': 'SOC',
#  'genre_ld': ['http://id.loc.gov/vocabulary/marcgt/doc',
#   'http://id.loc.gov/vocabulary/marcgt/bib',
#   'http://id.loc.gov/vocabulary/marcgt/fic'],
#  'genre|P136__wikidata': ['modernist literature|Q971480',
#   'experimental literature|Q1384425',
#   'literary fiction|Q6647667',
#   'metafiction|Q531067',
#   'serialized fiction|Q1347298',
#   'autobiography|Q4184'],
#  'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; Paris, France',
#  'gnd_id|P227__wikidata': '4099246-9',
#  'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#  'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917375',
#  'has_edition_or_translation|P747__wikidata': ['Ulysses (2004 German translation)|Q15996608',
#   'Ulysses|Q19020726',
#   'Ulysses (1986)|Q28599480',
#   'Ulysses (1932)|Q28599496',
#   'Ulysses (1934)|Q28599520',
#   'Ulysses (1936)|Q28599521',
#   'Ulysses (1960)|Q28599523',
#   'Ulysses (1961)|Q28599525',
#   'Ulysses (1984)|Q28599531',
#   'Ulysses (2004)|Q28599849',
#   'Iliada|Q33182025',
#   'Ulysses (1935)|Q104191512'],
#  'has_part_or_parts|P527__wikidata': ['Telemachus|Q28601581',
#   'Nestor|Q28601624',
#   'Proteus|Q28601724',
#   'Calypso|Q28601800',
#   'Lotus-eaters|Q28602222',
#   'Hades|Q28602572',
#   'Aeolus|Q28602745',
#   'Lestrygonians|Q28647765',
#   'Scylla and Charybdis|Q28657069',
#   'Wandering Rocks|Q28709812',
#   'Sirens|Q56103204',
#   'Cyclops|Q56103151',
#   'Nausikaa|Q56103127',
#   'Oxen of the Sun|Q56103091',
#   'Circe|Q56103050',
#   'Eumaeus|Q56103019',
#   'Ithaca|Q56102932',
#   'Penelope|Q38138028'],
#  'htid': 'mdp.39015005917375',
#  'id_orig__txtlab': '296',
#  'idref_id|P269__wikidata': '027383113',
#  'image|P18__wikidata': 'UlyssesCover.jpg',
#  'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#  'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#  'instance_of|P31__wikidata': 'literary work|Q7725634',
#  'isbn': '0824043758',
#  'label__wikidata': 'Ulysses',
#  'language': 'eng',
#  'language__txtlab': 'English',
#  'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#  'last_line|P3132__wikidata': 'I said yes I will Yes.',
#  'last_rights_update_date': 20170411,
#  'lcc': 'PR6019.O9U4 1984',
#  'lccn': '84004094',
#  'length__txtlab': '264170',
#  'libraries__chicago': '118',
#  'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#  'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#  'main_entity_of_page': ['https://catalog.hathitrust.org/Record/000249715',
#   'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#   'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#  'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#  'modernist_commons_id|P9365__wikidata': '15',
#  'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#  'name_first__markmark': 'James',
#  'name_last__markmark': 'Joyce',
#  'name_middle__markmark': 'Augustine Aloysius',
#  'narrative_location|P840__wikidata': ['Dublin|Q1761',
#   'James Joyce Tower and Museum|Q2062702',
#   'National Library of Ireland|Q1672830',
#   'Sandymount Strand|Q7417543',
#   'Glasnevin Cemetery|Q1263215',
#   "Freeman's Journal|Q5500969",
#   "Davy Byrne's pub|Q5242183",
#   'Dalkey|Q659895',
#   'Cabra (Dublin)|Q2088319',
#   'Grafton Street|Q135501',
#   "O'Connell Bridge|Q1766409",
#   "Nelson's Pillar|Q2350741",
#   'National Maternity Hospital, Dublin|Q13156901',
#   '#7 Eccles street|Q28601860'],
#  'nation__markmark': 'Irish',
#  'national_diet_library_id|P349__wikidata': '00971887',
#  'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#  'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#  'nationality__chicago': 'Irish',
#  'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#  'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#  'nnl_item_id|P3959__wikidata': '001210300',
#  'notes__markmark': 'serialized 1918-1920',
#  'num_words__markmark': '282576',
#  'number_of_parts_of_this_work|P2635__wikidata': {'amount': '+18',
#   'unit': 'http://www.wikidata.org/entity/Q1983062'},
#  'oclc': '10505634',
#  'oclc_work_id|P5331__wikidata': '395796',
#  'ocr_accuracy__markmark': '0.771848989298',
#  'open_library_id|P648__wikidata': 'OL86344W',
#  'page_count': 600,
#  'person__txtlab': 'first',
#  'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#  'pub_date': 1900,
#  'pub_place': 'New York (State)',
#  'pub_place_ld': {'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#   'name': 'New York (State)'},
#  'publ_city__chicago': 'Paris',
#  'publ_date__chicago': '1922',
#  'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#  'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#  'publisher': 'Garland Pub.',
#  'publisher__chicago': 'Shakespeare & Co',
#  'publisher_ld': {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'Garland Pub.'},
#  'publisher|P123__wikidata': ['Shakespeare and Company|Q1503157',
#   'Sylvia Beach|Q265562'],
#  'race_ethnicity__chicago': 'Caucasian',
#  'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#  'significant_event|P793__wikidata': ['Bloomsday|Q804551',
#   'Obscenity trial of Ulysses in The Little Review|Q16153541',
#   'United States v. One Book Called Ulysses|Q2895062'],
#  'source__chicago': 'k',
#  'source_institution': 'MIU',
#  'source_institution_ld': {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'MIU'},
#  'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#  'title': 'Ulysses /',
#  'title__chicago': 'Ulysses',
#  'title__markmark': 'Ulysses',
#  'title__txtlab': 'Ulysses',
#  'title|P1476__wikidata': 'Ulysses',
#  'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#  'type': ['DataFeedItem', 'Book'],
#  'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#  'viaf_id|P214__wikidata': '174999739',
#  'what__wikidata': 'literary work',
#  'year__chicago': '1922',
#  'year__markmark': '1922',
#  'year__txtlab': '1922'}

# %%
with log:
    thr = TextHathiRecord(id='htrn/000249715', _corpus=C)
    thrmeta = thr.meta#data(remote=True,force=True)
thrmeta
# Out:
# [18:32:34] lltk.text.text.__init__( <- id = htrn/000249715, corpus = HathiCorpus(hathi) )
# [18:32:34] lltk.text.text.__init__( TextHathiRecord(id = htrn/000249715, corpus = HathiCorpus(hathi)) )
# [18:32:34] lltk.text.text.__init__( Loading source? None )
# [18:32:34] lltk.text.text.Text( <- id = _chicago/00004881 )
# [18:32:34] lltk.text.text.Text( <- addr = _chicago/00004881 )
# [18:32:34] lltk.text.text.Text( -> TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.Text( <- id = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:34] lltk.text.text.Text( <- addr = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:34] lltk.text.text.Text( -> TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.Text( <- id = _markmark/Joyce,_James.Ulysses )
# [18:32:34] lltk.text.text.Text( <- addr = _markmark/Joyce,_James.Ulysses )
# [18:32:34] lltk.text.text.Text( -> TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.Text( <- id = _wikidata/Q6511 )
# [18:32:34] lltk.text.text.Text( <- addr = _wikidata/Q6511 )
# [18:32:34] lltk.text.text.Text( -> TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# {'id': 'htrn/000249715',
#  'id__chicago': '00004881',
#  'id__hathi': 'htid/mdp.39015005917359',
#  'id__markmark': 'Joyce,_James.Ulysses',
#  'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#  'id__wikidata': 'Q6511',
#  'access_profile': 'google',
#  'access_rights': 'pd',
#  'ausstage_work_id|P8294__wikidata': '3970',
#  'auth_first__chicago': 'James',
#  'auth_id__chicago': 'A_01848',
#  'auth_last__chicago': 'Joyce',
#  'author__chicago': 'Joyce, James',
#  'author__markmark': 'Joyce, James Augustine Aloysius',
#  'author__txtlab': 'Joyce,James',
#  'author|P50__wikidata': 'James Joyce|Q6882',
#  'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#  'based_on|P144__wikidata': 'Odyssey|Q35160',
#  'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#  'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#  'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#  'book_id__chicago': '4881',
#  'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#  'bookogs_work_id|P8211__wikidata': '405385',
#  'category': 'English literature',
#  'characters|P674__wikidata': ['Leopold Bloom|Q573988',
#   'Molly Bloom|Q2296791',
#   'Stephen Dedalus|Q543671',
#   'May Goulding Dedalus|Q16910626',
#   'Simon Dedalus|Q7518595',
#   'Milly Bloom|Q6860161',
#   'Buck Mulligan|Q4982905',
#   'Michael Cusack|Q1927217',
#   'George William Russell|Q366070',
#   'William Magee|Q18880357',
#   'Thomas William Lyster|Q1416892',
#   'Joseph Patrick Nannetti|Q1707785',
#   'Richard Irvine Best|Q7326690',
#   'David Sheehy|Q5239704',
#   'John Hooper|Q6239779',
#   'Tisdall Farrell|Q28575591',
#   'Haines|Q28601692',
#   'Martha Clifford|Q28602262',
#   'Garrett Deasy|Q16739979',
#   "C. P. M'Coy|Q28602472",
#   'Corny Kelleher (Ulysses character)|Q16910929',
#   'Jack Power (Ulysses character)|Q16919411',
#   'Martin Cunningham|Q16739992'],
#  'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#  'contributor': ['Joyce, James, 1882-1941',
#   'Melchior, Claus',
#   'Steppe, Wolfhard',
#   'Gabler, Hans Walter, 1938-'],
#  'contributor_ld': [{'id': 'http://www.viaf.org/viaf/44300643',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Joyce, James, 1882-1941'},
#   {'id': 'http://www.viaf.org/viaf/54210018',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Melchior, Claus'},
#   {'id': 'http://www.viaf.org/viaf/14785516',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Steppe, Wolfhard'},
#   {'id': 'http://www.viaf.org/viaf/108429204',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Gabler, Hans Walter, 1938-'}],
#  'copyright_status|P6216__wikidata': ['public domain|Q19652',
#   'public domain|Q19652'],
#  'corpus__markmark': 'MarkMark',
#  'country_of_origin|P495__wikidata': ['France|Q142',
#   'United States of America|Q30',
#   'French Third Republic|Q70802',
#   'United Kingdom of Great Britain and Ireland|Q174193'],
#  'date__txtlab': '1922',
#  'date_b__chicago': '1882',
#  'date_created': 20200209,
#  'date_d__chicago': '1941',
#  'default_page_section': 'body',
#  'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#  'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#  'dob__markmark': '1882.0',
#  'dod__markmark': '1941.0',
#  'education__chicago': 'U Coll Dublin',
#  'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#  'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#  'enumeration_chronology': 'v.1',
#  'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#  'filename__chicago': '00004881.txt',
#  'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the stairhead, bearing a bowl of lather on which a mirror and a razor lay crossed.',
#  'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#  'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#  'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#  'freebase_id|P646__wikidata': '/m/0f3dt',
#  'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#  'gender__chicago': 'M',
#  'gender__markmark': 'M',
#  'gender__txtlab': 'male',
#  'genre': ['document (computer)', 'bibliography', 'fiction'],
#  'genre__chicago': 'SOC',
#  'genre_ld': ['http://id.loc.gov/vocabulary/marcgt/doc',
#   'http://id.loc.gov/vocabulary/marcgt/bib',
#   'http://id.loc.gov/vocabulary/marcgt/fic'],
#  'genre|P136__wikidata': ['modernist literature|Q971480',
#   'experimental literature|Q1384425',
#   'literary fiction|Q6647667',
#   'metafiction|Q531067',
#   'serialized fiction|Q1347298',
#   'autobiography|Q4184'],
#  'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; Paris, France',
#  'gnd_id|P227__wikidata': '4099246-9',
#  'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#  'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917359',
#  'has_edition_or_translation|P747__wikidata': ['Ulysses (2004 German translation)|Q15996608',
#   'Ulysses|Q19020726',
#   'Ulysses (1986)|Q28599480',
#   'Ulysses (1932)|Q28599496',
#   'Ulysses (1934)|Q28599520',
#   'Ulysses (1936)|Q28599521',
#   'Ulysses (1960)|Q28599523',
#   'Ulysses (1961)|Q28599525',
#   'Ulysses (1984)|Q28599531',
#   'Ulysses (2004)|Q28599849',
#   'Iliada|Q33182025',
#   'Ulysses (1935)|Q104191512'],
#  'has_part_or_parts|P527__wikidata': ['Telemachus|Q28601581',
#   'Nestor|Q28601624',
#   'Proteus|Q28601724',
#   'Calypso|Q28601800',
#   'Lotus-eaters|Q28602222',
#   'Hades|Q28602572',
#   'Aeolus|Q28602745',
#   'Lestrygonians|Q28647765',
#   'Scylla and Charybdis|Q28657069',
#   'Wandering Rocks|Q28709812',
#   'Sirens|Q56103204',
#   'Cyclops|Q56103151',
#   'Nausikaa|Q56103127',
#   'Oxen of the Sun|Q56103091',
#   'Circe|Q56103050',
#   'Eumaeus|Q56103019',
#   'Ithaca|Q56102932',
#   'Penelope|Q38138028'],
#  'htid': 'mdp.39015005917359',
#  'id_orig__txtlab': '296',
#  'idref_id|P269__wikidata': '027383113',
#  'image|P18__wikidata': 'UlyssesCover.jpg',
#  'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#  'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#  'instance_of|P31__wikidata': 'literary work|Q7725634',
#  'isbn': '0824043758',
#  'label__wikidata': 'Ulysses',
#  'language': 'eng',
#  'language__txtlab': 'English',
#  'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#  'last_line|P3132__wikidata': 'I said yes I will Yes.',
#  'last_rights_update_date': 20161119,
#  'lcc': 'PR6019.O9U4 1984',
#  'lccn': '84004094',
#  'length__txtlab': '264170',
#  'libraries__chicago': '118',
#  'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#  'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#  'main_entity_of_page': ['https://catalog.hathitrust.org/Record/000249715',
#   'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#   'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#  'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#  'modernist_commons_id|P9365__wikidata': '15',
#  'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#  'name_first__markmark': 'James',
#  'name_last__markmark': 'Joyce',
#  'name_middle__markmark': 'Augustine Aloysius',
#  'narrative_location|P840__wikidata': ['Dublin|Q1761',
#   'James Joyce Tower and Museum|Q2062702',
#   'National Library of Ireland|Q1672830',
#   'Sandymount Strand|Q7417543',
#   'Glasnevin Cemetery|Q1263215',
#   "Freeman's Journal|Q5500969",
#   "Davy Byrne's pub|Q5242183",
#   'Dalkey|Q659895',
#   'Cabra (Dublin)|Q2088319',
#   'Grafton Street|Q135501',
#   "O'Connell Bridge|Q1766409",
#   "Nelson's Pillar|Q2350741",
#   'National Maternity Hospital, Dublin|Q13156901',
#   '#7 Eccles street|Q28601860'],
#  'nation__markmark': 'Irish',
#  'national_diet_library_id|P349__wikidata': '00971887',
#  'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#  'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#  'nationality__chicago': 'Irish',
#  'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#  'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#  'nnl_item_id|P3959__wikidata': '001210300',
#  'notes__markmark': 'serialized 1918-1920',
#  'num_words__markmark': '282576',
#  'number_of_parts_of_this_work|P2635__wikidata': {'amount': '+18',
#   'unit': 'http://www.wikidata.org/entity/Q1983062'},
#  'oclc': '10505634',
#  'oclc_work_id|P5331__wikidata': '395796',
#  'ocr_accuracy__markmark': '0.771848989298',
#  'open_library_id|P648__wikidata': 'OL86344W',
#  'page_count': 658,
#  'person__txtlab': 'first',
#  'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#  'pub_date': 1900,
#  'pub_place': 'New York (State)',
#  'pub_place_ld': {'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#   'name': 'New York (State)'},
#  'publ_city__chicago': 'Paris',
#  'publ_date__chicago': '1922',
#  'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#  'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#  'publisher': 'Garland Pub.',
#  'publisher__chicago': 'Shakespeare & Co',
#  'publisher_ld': {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'Garland Pub.'},
#  'publisher|P123__wikidata': ['Shakespeare and Company|Q1503157',
#   'Sylvia Beach|Q265562'],
#  'race_ethnicity__chicago': 'Caucasian',
#  'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#  'significant_event|P793__wikidata': ['Bloomsday|Q804551',
#   'Obscenity trial of Ulysses in The Little Review|Q16153541',
#   'United States v. One Book Called Ulysses|Q2895062'],
#  'source__chicago': 'k',
#  'source_institution': 'MIU',
#  'source_institution_ld': {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'MIU'},
#  'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#  'title': 'Ulysses /',
#  'title__chicago': 'Ulysses',
#  'title__markmark': 'Ulysses',
#  'title__txtlab': 'Ulysses',
#  'title|P1476__wikidata': 'Ulysses',
#  'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#  'type': ['DataFeedItem', 'Book'],
#  'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#  'viaf_id|P214__wikidata': '174999739',
#  'what__wikidata': 'literary work',
#  'year__chicago': '1922',
#  'year__markmark': '1922',
#  'year__txtlab': '1922'}

# %%
with log:
    thr2 = Text('_hathi/htrn/000249715')
    thrmeta2 = thr.meta#data(remote=True,force=True)
thrmeta2
# Out:
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htrn/000249715 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htrn/000249715 )
# [18:32:34] lltk.corpus.corpus.Corpus( <- id = hathi )
# [18:32:34] lltk.corpus.corpus.Corpus( -> HathiCorpus(hathi) )
# [18:32:34] lltk.corpus.corpus.text( <- id = htrn/000249715, corpus = HathiCorpus(hathi) )
# [18:32:34] lltk.corpus.corpus.text( -> TextHathiRecord(_hathi/htrn/000249715) )
# [18:32:34] lltk.text.text.Text( -> TextHathiRecord(_hathi/htrn/000249715) )
# [18:32:34] lltk.text.text.Text( <- id = _chicago/00004881 )
# [18:32:34] lltk.text.text.Text( <- addr = _chicago/00004881 )
# [18:32:34] lltk.text.text.Text( -> TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.Text( <- id = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:34] lltk.text.text.Text( <- addr = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:34] lltk.text.text.Text( -> TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.Text( <- id = _markmark/Joyce,_James.Ulysses )
# [18:32:34] lltk.text.text.Text( <- addr = _markmark/Joyce,_James.Ulysses )
# [18:32:34] lltk.text.text.Text( -> TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.Text( <- id = _wikidata/Q6511 )
# [18:32:34] lltk.text.text.Text( <- addr = _wikidata/Q6511 )
# [18:32:34] lltk.text.text.Text( -> TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:34] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:34] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextChicago(_chicago/00004881) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:34] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# {'id': 'htrn/000249715',
#  'id__chicago': '00004881',
#  'id__hathi': 'htid/mdp.39015005917359',
#  'id__markmark': 'Joyce,_James.Ulysses',
#  'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#  'id__wikidata': 'Q6511',
#  'access_profile': 'google',
#  'access_rights': 'pd',
#  'ausstage_work_id|P8294__wikidata': '3970',
#  'auth_first__chicago': 'James',
#  'auth_id__chicago': 'A_01848',
#  'auth_last__chicago': 'Joyce',
#  'author__chicago': 'Joyce, James',
#  'author__markmark': 'Joyce, James Augustine Aloysius',
#  'author__txtlab': 'Joyce,James',
#  'author|P50__wikidata': 'James Joyce|Q6882',
#  'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#  'based_on|P144__wikidata': 'Odyssey|Q35160',
#  'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#  'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#  'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#  'book_id__chicago': '4881',
#  'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#  'bookogs_work_id|P8211__wikidata': '405385',
#  'category': 'English literature',
#  'characters|P674__wikidata': ['Leopold Bloom|Q573988',
#   'Molly Bloom|Q2296791',
#   'Stephen Dedalus|Q543671',
#   'May Goulding Dedalus|Q16910626',
#   'Simon Dedalus|Q7518595',
#   'Milly Bloom|Q6860161',
#   'Buck Mulligan|Q4982905',
#   'Michael Cusack|Q1927217',
#   'George William Russell|Q366070',
#   'William Magee|Q18880357',
#   'Thomas William Lyster|Q1416892',
#   'Joseph Patrick Nannetti|Q1707785',
#   'Richard Irvine Best|Q7326690',
#   'David Sheehy|Q5239704',
#   'John Hooper|Q6239779',
#   'Tisdall Farrell|Q28575591',
#   'Haines|Q28601692',
#   'Martha Clifford|Q28602262',
#   'Garrett Deasy|Q16739979',
#   "C. P. M'Coy|Q28602472",
#   'Corny Kelleher (Ulysses character)|Q16910929',
#   'Jack Power (Ulysses character)|Q16919411',
#   'Martin Cunningham|Q16739992'],
#  'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#  'contributor': ['Joyce, James, 1882-1941',
#   'Melchior, Claus',
#   'Steppe, Wolfhard',
#   'Gabler, Hans Walter, 1938-'],
#  'contributor_ld': [{'id': 'http://www.viaf.org/viaf/44300643',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Joyce, James, 1882-1941'},
#   {'id': 'http://www.viaf.org/viaf/54210018',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Melchior, Claus'},
#   {'id': 'http://www.viaf.org/viaf/14785516',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Steppe, Wolfhard'},
#   {'id': 'http://www.viaf.org/viaf/108429204',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Gabler, Hans Walter, 1938-'}],
#  'copyright_status|P6216__wikidata': ['public domain|Q19652',
#   'public domain|Q19652'],
#  'corpus__markmark': 'MarkMark',
#  'country_of_origin|P495__wikidata': ['France|Q142',
#   'United States of America|Q30',
#   'French Third Republic|Q70802',
#   'United Kingdom of Great Britain and Ireland|Q174193'],
#  'date__txtlab': '1922',
#  'date_b__chicago': '1882',
#  'date_created': 20200209,
#  'date_d__chicago': '1941',
#  'default_page_section': 'body',
#  'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#  'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#  'dob__markmark': '1882.0',
#  'dod__markmark': '1941.0',
#  'education__chicago': 'U Coll Dublin',
#  'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#  'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#  'enumeration_chronology': 'v.1',
#  'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#  'filename__chicago': '00004881.txt',
#  'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the stairhead, bearing a bowl of lather on which a mirror and a razor lay crossed.',
#  'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#  'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#  'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#  'freebase_id|P646__wikidata': '/m/0f3dt',
#  'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#  'gender__chicago': 'M',
#  'gender__markmark': 'M',
#  'gender__txtlab': 'male',
#  'genre': ['document (computer)', 'bibliography', 'fiction'],
#  'genre__chicago': 'SOC',
#  'genre_ld': ['http://id.loc.gov/vocabulary/marcgt/doc',
#   'http://id.loc.gov/vocabulary/marcgt/bib',
#   'http://id.loc.gov/vocabulary/marcgt/fic'],
#  'genre|P136__wikidata': ['modernist literature|Q971480',
#   'experimental literature|Q1384425',
#   'literary fiction|Q6647667',
#   'metafiction|Q531067',
#   'serialized fiction|Q1347298',
#   'autobiography|Q4184'],
#  'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; Paris, France',
#  'gnd_id|P227__wikidata': '4099246-9',
#  'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#  'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917359',
#  'has_edition_or_translation|P747__wikidata': ['Ulysses (2004 German translation)|Q15996608',
#   'Ulysses|Q19020726',
#   'Ulysses (1986)|Q28599480',
#   'Ulysses (1932)|Q28599496',
#   'Ulysses (1934)|Q28599520',
#   'Ulysses (1936)|Q28599521',
#   'Ulysses (1960)|Q28599523',
#   'Ulysses (1961)|Q28599525',
#   'Ulysses (1984)|Q28599531',
#   'Ulysses (2004)|Q28599849',
#   'Iliada|Q33182025',
#   'Ulysses (1935)|Q104191512'],
#  'has_part_or_parts|P527__wikidata': ['Telemachus|Q28601581',
#   'Nestor|Q28601624',
#   'Proteus|Q28601724',
#   'Calypso|Q28601800',
#   'Lotus-eaters|Q28602222',
#   'Hades|Q28602572',
#   'Aeolus|Q28602745',
#   'Lestrygonians|Q28647765',
#   'Scylla and Charybdis|Q28657069',
#   'Wandering Rocks|Q28709812',
#   'Sirens|Q56103204',
#   'Cyclops|Q56103151',
#   'Nausikaa|Q56103127',
#   'Oxen of the Sun|Q56103091',
#   'Circe|Q56103050',
#   'Eumaeus|Q56103019',
#   'Ithaca|Q56102932',
#   'Penelope|Q38138028'],
#  'htid': 'mdp.39015005917359',
#  'id_orig__txtlab': '296',
#  'idref_id|P269__wikidata': '027383113',
#  'image|P18__wikidata': 'UlyssesCover.jpg',
#  'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#  'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#  'instance_of|P31__wikidata': 'literary work|Q7725634',
#  'isbn': '0824043758',
#  'label__wikidata': 'Ulysses',
#  'language': 'eng',
#  'language__txtlab': 'English',
#  'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#  'last_line|P3132__wikidata': 'I said yes I will Yes.',
#  'last_rights_update_date': 20161119,
#  'lcc': 'PR6019.O9U4 1984',
#  'lccn': '84004094',
#  'length__txtlab': '264170',
#  'libraries__chicago': '118',
#  'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#  'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#  'main_entity_of_page': ['https://catalog.hathitrust.org/Record/000249715',
#   'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#   'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#  'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#  'modernist_commons_id|P9365__wikidata': '15',
#  'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#  'name_first__markmark': 'James',
#  'name_last__markmark': 'Joyce',
#  'name_middle__markmark': 'Augustine Aloysius',
#  'narrative_location|P840__wikidata': ['Dublin|Q1761',
#   'James Joyce Tower and Museum|Q2062702',
#   'National Library of Ireland|Q1672830',
#   'Sandymount Strand|Q7417543',
#   'Glasnevin Cemetery|Q1263215',
#   "Freeman's Journal|Q5500969",
#   "Davy Byrne's pub|Q5242183",
#   'Dalkey|Q659895',
#   'Cabra (Dublin)|Q2088319',
#   'Grafton Street|Q135501',
#   "O'Connell Bridge|Q1766409",
#   "Nelson's Pillar|Q2350741",
#   'National Maternity Hospital, Dublin|Q13156901',
#   '#7 Eccles street|Q28601860'],
#  'nation__markmark': 'Irish',
#  'national_diet_library_id|P349__wikidata': '00971887',
#  'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#  'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#  'nationality__chicago': 'Irish',
#  'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#  'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#  'nnl_item_id|P3959__wikidata': '001210300',
#  'notes__markmark': 'serialized 1918-1920',
#  'num_words__markmark': '282576',
#  'number_of_parts_of_this_work|P2635__wikidata': {'amount': '+18',
#   'unit': 'http://www.wikidata.org/entity/Q1983062'},
#  'oclc': '10505634',
#  'oclc_work_id|P5331__wikidata': '395796',
#  'ocr_accuracy__markmark': '0.771848989298',
#  'open_library_id|P648__wikidata': 'OL86344W',
#  'page_count': 658,
#  'person__txtlab': 'first',
#  'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#  'pub_date': 1900,
#  'pub_place': 'New York (State)',
#  'pub_place_ld': {'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#   'name': 'New York (State)'},
#  'publ_city__chicago': 'Paris',
#  'publ_date__chicago': '1922',
#  'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#  'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#  'publisher': 'Garland Pub.',
#  'publisher__chicago': 'Shakespeare & Co',
#  'publisher_ld': {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'Garland Pub.'},
#  'publisher|P123__wikidata': ['Shakespeare and Company|Q1503157',
#   'Sylvia Beach|Q265562'],
#  'race_ethnicity__chicago': 'Caucasian',
#  'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#  'significant_event|P793__wikidata': ['Bloomsday|Q804551',
#   'Obscenity trial of Ulysses in The Little Review|Q16153541',
#   'United States v. One Book Called Ulysses|Q2895062'],
#  'source__chicago': 'k',
#  'source_institution': 'MIU',
#  'source_institution_ld': {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'MIU'},
#  'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#  'title': 'Ulysses /',
#  'title__chicago': 'Ulysses',
#  'title__markmark': 'Ulysses',
#  'title__txtlab': 'Ulysses',
#  'title|P1476__wikidata': 'Ulysses',
#  'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#  'type': ['DataFeedItem', 'Book'],
#  'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#  'viaf_id|P214__wikidata': '174999739',
#  'what__wikidata': 'literary work',
#  'year__chicago': '1922',
#  'year__markmark': '1922',
#  'year__txtlab': '1922'}

# %%
thrmeta == thrmeta2, thrmeta is thrmeta2, thr == thr2, thr is thr2
# Out:
# (True, False, True, False)

# %%
thr.author, thr.year
# Out:
# ('Joyce, James, 1882-1941', nan)

# %%
with log: x=thr.metadata(remote=True,force=True)
x
# Out:
# [18:32:34] hathi.query( ('recordnumber', '000249715') )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.add_source( adding source vice versa )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.add_source( found match: (None, None) )
# [18:32:35] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'ausstage_work_id|P8294__wikidata': '3970',
#   'auth_first__chicago': 'James',
#   'auth_id__chicago': 'A_01848',
#   'auth_last__chicago': 'Joyce',
#   'author__chicago': 'Joyce, James',
#   'author__markmark': 'Joyce, James Augustine Aloysius',
#   'author__txtlab': 'Joyce,James',
#   'author|P50__wikidata': 'James Joyce|Q6882',
#   'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#   'based_on|P144__wikidata': 'Odyssey|Q35160',
#   'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#   'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#   'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#   'book_id__chicago': '4881',
#   'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#   'bookogs_work_id|P8211__wikidata': '405385',
#   'category': 'English literature',
#   'characters|P674__wikidata': [ 'Leopold Bloom|Q573988',
#                                  'Molly Bloom|Q2296791',
#                                  'Stephen Dedalus|Q543671',
#                                  'May Goulding Dedalus|Q16910626',
#                                  'Simon Dedalus|Q7518595',
#                                  'Milly Bloom|Q6860161',
#                                  'Buck Mulligan|Q4982905',
#                                  'Michael Cusack|Q1927217',
#                                  'George William Russell|Q366070',
#                                  'William Magee|Q18880357',
#                                  'Thomas William Lyster|Q1416892',
#                                  'Joseph Patrick Nannetti|Q1707785',
#                                  'Richard Irvine Best|Q7326690',
#                                  'David Sheehy|Q5239704',
#                                  'John Hooper|Q6239779',
#                                  'Tisdall Farrell|Q28575591',
#                                  'Haines|Q28601692',
#                                  'Martha Clifford|Q28602262',
#                                  'Garrett Deasy|Q16739979',
#                                  "C. P. M'Coy|Q28602472",
#                                  'Corny Kelleher (Ulysses character)|Q16910929',
#                                  'Jack Power (Ulysses character)|Q16919411',
#                                  'Martin Cunningham|Q16739992'],
#   'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'copyright_status|P6216__wikidata': [ 'public domain|Q19652',
#                                         'public domain|Q19652'],
#   'corpus__markmark': 'MarkMark',
#   'country_of_origin|P495__wikidata': [ 'France|Q142',
#                                         'United States of America|Q30',
#                                         'French Third Republic|Q70802',
#                                         'United Kingdom of Great Britain and '
#                                         'Ireland|Q174193'],
#   'date__txtlab': '1922',
#   'date_b__chicago': '1882',
#   'date_created': 20200209,
#   'date_d__chicago': '1941',
#   'default_page_section': 'body',
#   'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#   'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#   'dob__markmark': '1882.0',
#   'dod__markmark': '1941.0',
#   'education__chicago': 'U Coll Dublin',
#   'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#   'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#   'enumeration_chronology': 'v.1',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'filename__chicago': '00004881.txt',
#   'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the '
#                                 'stairhead, bearing a bowl of lather on which '
#                                 'a mirror and a razor lay crossed.',
#   'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#   'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#   'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#   'freebase_id|P646__wikidata': '/m/0f3dt',
#   'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#   'gender__chicago': 'M',
#   'gender__markmark': 'M',
#   'gender__txtlab': 'male',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre__chicago': 'SOC',
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'genre|P136__wikidata': [ 'modernist literature|Q971480',
#                             'experimental literature|Q1384425',
#                             'literary fiction|Q6647667',
#                             'metafiction|Q531067',
#                             'serialized fiction|Q1347298',
#                             'autobiography|Q4184'],
#   'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; '
#                         'Paris, France',
#   'gnd_id|P227__wikidata': '4099246-9',
#   'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#   'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917359',
#   'has_edition_or_translation|P747__wikidata': [ 'Ulysses (2004 German '
#                                                  'translation)|Q15996608',
#                                                  'Ulysses|Q19020726',
#                                                  'Ulysses (1986)|Q28599480',
#                                                  'Ulysses (1932)|Q28599496',
#                                                  'Ulysses (1934)|Q28599520',
#                                                  'Ulysses (1936)|Q28599521',
#                                                  'Ulysses (1960)|Q28599523',
#                                                  'Ulysses (1961)|Q28599525',
#                                                  'Ulysses (1984)|Q28599531',
#                                                  'Ulysses (2004)|Q28599849',
#                                                  'Iliada|Q33182025',
#                                                  'Ulysses (1935)|Q104191512'],
#   'has_part_or_parts|P527__wikidata': [ 'Telemachus|Q28601581',
#                                         'Nestor|Q28601624',
#                                         'Proteus|Q28601724',
#                                         'Calypso|Q28601800',
#                                         'Lotus-eaters|Q28602222',
#                                         'Hades|Q28602572',
#                                         'Aeolus|Q28602745',
#                                         'Lestrygonians|Q28647765',
#                                         'Scylla and Charybdis|Q28657069',
#                                         'Wandering Rocks|Q28709812',
#                                         'Sirens|Q56103204',
#                                         'Cyclops|Q56103151',
#                                         'Nausikaa|Q56103127',
#                                         'Oxen of the Sun|Q56103091',
#                                         'Circe|Q56103050',
#                                         'Eumaeus|Q56103019',
#                                         'Ithaca|Q56102932',
#                                         'Penelope|Q38138028'],
#   'htid': 'uc1.31822006892251',
#   'htids': [ 'uc1.31822006892251',
#              'mdp.39015005917359',
#              'uc1.31822001992726',
#              'mdp.39015005917367',
#              'uc1.31822001992759',
#              'mdp.39015005917375'],
#   'id': 'htrn/000249715',
#   'id__chicago': '00004881',
#   'id__hathi': 'htid/mdp.39015005917359',
#   'id__markmark': 'Joyce,_James.Ulysses',
#   'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#   'id__wikidata': 'Q6511',
#   'id_orig__txtlab': '296',
#   'idref_id|P269__wikidata': '027383113',
#   'image|P18__wikidata': 'UlyssesCover.jpg',
#   'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#   'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#   'instance_of|P31__wikidata': 'literary work|Q7725634',
#   'isbn': '9780824043759',
#   'isbns': ['9780824043759', '9780824043759', '9780824043759'],
#   'label__wikidata': 'Ulysses',
#   'language': 'eng',
#   'language__txtlab': 'English',
#   'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#   'last_line|P3132__wikidata': 'I said yes I will Yes.',
#   'last_rights_update_date': 20161119,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'length__txtlab': '264170',
#   'libraries__chicago': '118',
#   'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#   'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'modernist_commons_id|P9365__wikidata': '15',
#   'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#   'name_first__markmark': 'James',
#   'name_last__markmark': 'Joyce',
#   'name_middle__markmark': 'Augustine Aloysius',
#   'narrative_location|P840__wikidata': [ 'Dublin|Q1761',
#                                          'James Joyce Tower and '
#                                          'Museum|Q2062702',
#                                          'National Library of Ireland|Q1672830',
#                                          'Sandymount Strand|Q7417543',
#                                          'Glasnevin Cemetery|Q1263215',
#                                          "Freeman's Journal|Q5500969",
#                                          "Davy Byrne's pub|Q5242183",
#                                          'Dalkey|Q659895',
#                                          'Cabra (Dublin)|Q2088319',
#                                          'Grafton Street|Q135501',
#                                          "O'Connell Bridge|Q1766409",
#                                          "Nelson's Pillar|Q2350741",
#                                          'National Maternity Hospital, '
#                                          'Dublin|Q13156901',
#                                          '#7 Eccles street|Q28601860'],
#   'nation__markmark': 'Irish',
#   'national_diet_library_id|P349__wikidata': '00971887',
#   'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#   'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#   'nationality__chicago': 'Irish',
#   'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#   'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#   'nnl_item_id|P3959__wikidata': '001210300',
#   'notes__markmark': 'serialized 1918-1920',
#   'num_vols': 6,
#   'num_words__markmark': '282576',
#   'number_of_parts_of_this_work|P2635__wikidata': { 'amount': '+18',
#                                                     'unit': 'http://www.wikidata.org/entity/Q1983062'},
#   'oclc': '10505634',
#   'oclc_work_id|P5331__wikidata': '395796',
#   'ocr_accuracy__markmark': '0.771848989298',
#   'open_library_id|P648__wikidata': 'OL86344W',
#   'page_count': 658,
#   'person__txtlab': 'first',
#   'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publ_city__chicago': 'Paris',
#   'publ_date__chicago': '1922',
#   'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#   'publishDate': '1900',
#   'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#   'publisher': 'Garland Pub.',
#   'publisher__chicago': 'Shakespeare & Co',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'publisher|P123__wikidata': [ 'Shakespeare and Company|Q1503157',
#                                 'Sylvia Beach|Q265562'],
#   'race_ethnicity__chicago': 'Caucasian',
#   'recordURL': 'https://catalog.hathitrust.org/Record/000249715',
#   'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#   'significant_event|P793__wikidata': [ 'Bloomsday|Q804551',
#                                         'Obscenity trial of Ulysses in The '
#                                         'Little Review|Q16153541',
#                                         'United States v. One Book Called '
#                                         'Ulysses|Q2895062'],
#   'source__chicago': 'k',
#   'source_institution': 'MIU',
#   'source_institution_ld': { 'name': 'MIU',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#   'title': 'Ulysses',
#   'title__chicago': 'Ulysses',
#   'title__markmark': 'Ulysses',
#   'title__txtlab': 'Ulysses',
#   'title|P1476__wikidata': 'Ulysses',
#   'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#   'viaf_id|P214__wikidata': '174999739',
#   'what__wikidata': 'literary work',
#   'year__chicago': '1922',
#   'year__markmark': '1922',
#   'year__txtlab': '1922'} )
# [18:32:35] lltk.text.text.Text( <- id = _chicago/00004881 )
# [18:32:35] lltk.text.text.Text( <- addr = _chicago/00004881 )
# [18:32:35] lltk.text.text.Text( -> TextChicago(_chicago/00004881) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.Text( <- id = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:35] lltk.text.text.Text( <- addr = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:35] lltk.text.text.Text( -> TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:35] lltk.text.text.Text( <- id = _markmark/Joyce,_James.Ulysses )
# [18:32:35] lltk.text.text.Text( <- addr = _markmark/Joyce,_James.Ulysses )
# [18:32:35] lltk.text.text.Text( -> TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.Text( <- id = _wikidata/Q6511 )
# [18:32:35] lltk.text.text.Text( <- addr = _wikidata/Q6511 )
# [18:32:35] lltk.text.text.Text( -> TextWikidataClass(_wikidata/Q6511) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextChicago(_chicago/00004881) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.model.wikidata.get_remote_sources( ... )
# [18:32:35] lltk.model.wikidata.wikidata( ... )
# [18:32:35] lltk.text.text.Text( <- id = _chicago/00004881 )
# [18:32:35] lltk.text.text.Text( <- addr = _chicago/00004881 )
# [18:32:35] lltk.text.text.Text( -> TextChicago(_chicago/00004881) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917367 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917375 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.Text( <- id = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:35] lltk.text.text.Text( <- addr = _txtlab/EN_1922_Joyce,James_Ulysses_Novel )
# [18:32:35] lltk.text.text.Text( -> TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:35] lltk.text.text.Text( <- id = _markmark/Joyce,_James.Ulysses )
# [18:32:35] lltk.text.text.Text( <- addr = _markmark/Joyce,_James.Ulysses )
# [18:32:35] lltk.text.text.Text( -> TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822006892251 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992726 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.Text( <- id = _wikidata/Q6511 )
# [18:32:35] lltk.text.text.Text( <- addr = _wikidata/Q6511 )
# [18:32:35] lltk.text.text.Text( -> TextWikidataClass(_wikidata/Q6511) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/uc1.31822001992759 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.Text( <- id = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( <- addr = _hathi/htid/mdp.39015005917359 )
# [18:32:35] lltk.text.text.Text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextChicago(_chicago/00004881) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:35] lltk.text.text.get_local_sources( found source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextChicago(_chicago/00004881) )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.2',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917367',
#   'htid': 'mdp.39015005917367',
#   'id': 'htid/mdp.39015005917367',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20161126,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 728,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'MIU',
#   'source_institution_ld': { 'name': 'MIU',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:35] lltk.text.text.cache( TextHathiVolume(_hathi/htid/mdp.39015005917367) )
# [18:32:35] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/mdp.39015005917367/meta.json )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.3',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917375',
#   'htid': 'mdp.39015005917375',
#   'id': 'htid/mdp.39015005917375',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20170411,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 600,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'MIU',
#   'source_institution_ld': { 'name': 'MIU',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:35] lltk.text.text.cache( TextHathiVolume(_hathi/htid/mdp.39015005917375) )
# [18:32:35] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/mdp.39015005917375/meta.json )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextTxtLab(_txtlab/EN_1922_Joyce,James_Ulysses_Novel) )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextMarkMark(_markmark/Joyce,_James.Ulysses) )
# [18:32:35] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:36] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.1',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/uc1.31822006892251',
#   'htid': 'uc1.31822006892251',
#   'id': 'htid/uc1.31822006892251',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20171202,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 656,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'UCSD',
#   'source_institution_ld': { 'name': 'UCSD',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:36] lltk.text.text.cache( TextHathiVolume(_hathi/htid/uc1.31822006892251) )
# [18:32:36] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/uc1.31822006892251/meta.json )
# [18:32:36] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:36] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.2',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/uc1.31822001992726',
#   'htid': 'uc1.31822001992726',
#   'id': 'htid/uc1.31822001992726',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20171203,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 728,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'UCSD',
#   'source_institution_ld': { 'name': 'UCSD',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:36] lltk.text.text.cache( TextHathiVolume(_hathi/htid/uc1.31822001992726) )
# [18:32:36] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/uc1.31822001992726/meta.json )
# [18:32:36] lltk.text.text.metadata( adding metadata from source: TextWikidataClass(_wikidata/Q6511) )
# [18:32:36] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:36] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.3',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/uc1.31822001992759',
#   'htid': 'uc1.31822001992759',
#   'id': 'htid/uc1.31822001992759',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20171203,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 600,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'UCSD',
#   'source_institution_ld': { 'name': 'UCSD',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:36] lltk.text.text.cache( TextHathiVolume(_hathi/htid/uc1.31822001992759) )
# [18:32:36] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/uc1.31822001992759/meta.json )
# [18:32:36] lltk.text.text.metadata( adding metadata from source: TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:36] lltk.text.text.metadata( { 'access_profile': 'google',
#   'access_rights': 'pd',
#   'category': 'English literature',
#   'contributor': [ 'Joyce, James, 1882-1941',
#                    'Melchior, Claus',
#                    'Steppe, Wolfhard',
#                    'Gabler, Hans Walter, 1938-'],
#   'contributor_ld': [ { 'id': 'http://www.viaf.org/viaf/44300643',
#                         'name': 'Joyce, James, 1882-1941',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/54210018',
#                         'name': 'Melchior, Claus',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/14785516',
#                         'name': 'Steppe, Wolfhard',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'},
#                       { 'id': 'http://www.viaf.org/viaf/108429204',
#                         'name': 'Gabler, Hans Walter, 1938-',
#                         'type': 'http://id.loc.gov/ontologies/bibframe/Person'}],
#   'date_created': 20200209,
#   'default_page_section': 'body',
#   'enumeration_chronology': 'v.1',
#   'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   'genre': ['document (computer)', 'bibliography', 'fiction'],
#   'genre_ld': [ 'http://id.loc.gov/vocabulary/marcgt/doc',
#                 'http://id.loc.gov/vocabulary/marcgt/bib',
#                 'http://id.loc.gov/vocabulary/marcgt/fic'],
#   'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917359',
#   'htid': 'mdp.39015005917359',
#   'id': 'htid/mdp.39015005917359',
#   'isbn': '0824043758',
#   'language': 'eng',
#   'last_rights_update_date': 20161119,
#   'lcc': 'PR6019.O9U4 1984',
#   'lccn': '84004094',
#   'main_entity_of_page': [ 'https://catalog.hathitrust.org/Record/000249715',
#                            'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#                            'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#   'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   'oclc': '10505634',
#   'page_count': 658,
#   'pub_date': 1900,
#   'pub_place': 'New York (State)',
#   'pub_place_ld': { 'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#                     'name': 'New York (State)',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Place'},
#   'publisher': 'Garland Pub.',
#   'publisher_ld': { 'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#                     'name': 'Garland Pub.',
#                     'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'source_institution': 'MIU',
#   'source_institution_ld': { 'name': 'MIU',
#                              'type': 'http://id.loc.gov/ontologies/bibframe/Organization'},
#   'title': 'Ulysses /',
#   'type': ['DataFeedItem', 'Book'],
#   'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text'} )
# [18:32:36] lltk.text.text.cache( TextHathiVolume(_hathi/htid/mdp.39015005917359) )
# [18:32:36] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htid/mdp.39015005917359/meta.json )
# [18:32:36] lltk.text.text.cache( TextHathiRecord(_hathi/htrn/000249715) )
# [18:32:36] lltk.text.text.cache_json( cached text meta in json: /Users/ryan/lltk_data/corpora/hathi/texts/htrn/000249715/meta.json )
# {'id': 'htrn/000249715',
#  'id__chicago': '00004881',
#  'id__hathi': 'htid/mdp.39015005917359',
#  'id__markmark': 'Joyce,_James.Ulysses',
#  'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#  'id__wikidata': 'Q6511',
#  'access_profile': 'google',
#  'access_rights': 'pd',
#  'ausstage_work_id|P8294__wikidata': '3970',
#  'auth_first__chicago': 'James',
#  'auth_id__chicago': 'A_01848',
#  'auth_last__chicago': 'Joyce',
#  'author__chicago': 'Joyce, James',
#  'author__markmark': 'Joyce, James Augustine Aloysius',
#  'author__txtlab': 'Joyce,James',
#  'author|P50__wikidata': 'James Joyce|Q6882',
#  'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#  'based_on|P144__wikidata': 'Odyssey|Q35160',
#  'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#  'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#  'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#  'book_id__chicago': '4881',
#  'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#  'bookogs_work_id|P8211__wikidata': '405385',
#  'category': 'English literature',
#  'characters|P674__wikidata': ['Leopold Bloom|Q573988',
#   'Molly Bloom|Q2296791',
#   'Stephen Dedalus|Q543671',
#   'May Goulding Dedalus|Q16910626',
#   'Simon Dedalus|Q7518595',
#   'Milly Bloom|Q6860161',
#   'Buck Mulligan|Q4982905',
#   'Michael Cusack|Q1927217',
#   'George William Russell|Q366070',
#   'William Magee|Q18880357',
#   'Thomas William Lyster|Q1416892',
#   'Joseph Patrick Nannetti|Q1707785',
#   'Richard Irvine Best|Q7326690',
#   'David Sheehy|Q5239704',
#   'John Hooper|Q6239779',
#   'Tisdall Farrell|Q28575591',
#   'Haines|Q28601692',
#   'Martha Clifford|Q28602262',
#   'Garrett Deasy|Q16739979',
#   "C. P. M'Coy|Q28602472",
#   'Corny Kelleher (Ulysses character)|Q16910929',
#   'Jack Power (Ulysses character)|Q16919411',
#   'Martin Cunningham|Q16739992'],
#  'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#  'contributor': ['Joyce, James, 1882-1941',
#   'Melchior, Claus',
#   'Steppe, Wolfhard',
#   'Gabler, Hans Walter, 1938-'],
#  'contributor_ld': [{'id': 'http://www.viaf.org/viaf/44300643',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Joyce, James, 1882-1941'},
#   {'id': 'http://www.viaf.org/viaf/54210018',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Melchior, Claus'},
#   {'id': 'http://www.viaf.org/viaf/14785516',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Steppe, Wolfhard'},
#   {'id': 'http://www.viaf.org/viaf/108429204',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Gabler, Hans Walter, 1938-'}],
#  'copyright_status|P6216__wikidata': ['public domain|Q19652',
#   'public domain|Q19652'],
#  'corpus__markmark': 'MarkMark',
#  'country_of_origin|P495__wikidata': ['France|Q142',
#   'United States of America|Q30',
#   'French Third Republic|Q70802',
#   'United Kingdom of Great Britain and Ireland|Q174193'],
#  'date__txtlab': '1922',
#  'date_b__chicago': '1882',
#  'date_created': 20200209,
#  'date_d__chicago': '1941',
#  'default_page_section': 'body',
#  'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#  'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#  'dob__markmark': '1882.0',
#  'dod__markmark': '1941.0',
#  'education__chicago': 'U Coll Dublin',
#  'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#  'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#  'enumeration_chronology': 'v.1',
#  'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#  'filename__chicago': '00004881.txt',
#  'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the stairhead, bearing a bowl of lather on which a mirror and a razor lay crossed.',
#  'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#  'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#  'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#  'freebase_id|P646__wikidata': '/m/0f3dt',
#  'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#  'gender__chicago': 'M',
#  'gender__markmark': 'M',
#  'gender__txtlab': 'male',
#  'genre': ['document (computer)', 'bibliography', 'fiction'],
#  'genre__chicago': 'SOC',
#  'genre_ld': ['http://id.loc.gov/vocabulary/marcgt/doc',
#   'http://id.loc.gov/vocabulary/marcgt/bib',
#   'http://id.loc.gov/vocabulary/marcgt/fic'],
#  'genre|P136__wikidata': ['modernist literature|Q971480',
#   'experimental literature|Q1384425',
#   'literary fiction|Q6647667',
#   'metafiction|Q531067',
#   'serialized fiction|Q1347298',
#   'autobiography|Q4184'],
#  'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; Paris, France',
#  'gnd_id|P227__wikidata': '4099246-9',
#  'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#  'handle_url': 'http://hdl.handle.net/2027/mdp.39015005917359',
#  'has_edition_or_translation|P747__wikidata': ['Ulysses (2004 German translation)|Q15996608',
#   'Ulysses|Q19020726',
#   'Ulysses (1986)|Q28599480',
#   'Ulysses (1932)|Q28599496',
#   'Ulysses (1934)|Q28599520',
#   'Ulysses (1936)|Q28599521',
#   'Ulysses (1960)|Q28599523',
#   'Ulysses (1961)|Q28599525',
#   'Ulysses (1984)|Q28599531',
#   'Ulysses (2004)|Q28599849',
#   'Iliada|Q33182025',
#   'Ulysses (1935)|Q104191512'],
#  'has_part_or_parts|P527__wikidata': ['Telemachus|Q28601581',
#   'Nestor|Q28601624',
#   'Proteus|Q28601724',
#   'Calypso|Q28601800',
#   'Lotus-eaters|Q28602222',
#   'Hades|Q28602572',
#   'Aeolus|Q28602745',
#   'Lestrygonians|Q28647765',
#   'Scylla and Charybdis|Q28657069',
#   'Wandering Rocks|Q28709812',
#   'Sirens|Q56103204',
#   'Cyclops|Q56103151',
#   'Nausikaa|Q56103127',
#   'Oxen of the Sun|Q56103091',
#   'Circe|Q56103050',
#   'Eumaeus|Q56103019',
#   'Ithaca|Q56102932',
#   'Penelope|Q38138028'],
#  'htid': 'mdp.39015005917359',
#  'htids': ['uc1.31822006892251',
#   'mdp.39015005917359',
#   'uc1.31822001992726',
#   'mdp.39015005917367',
#   'uc1.31822001992759',
#   'mdp.39015005917375'],
#  'id_orig__txtlab': '296',
#  'idref_id|P269__wikidata': '027383113',
#  'image|P18__wikidata': 'UlyssesCover.jpg',
#  'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#  'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#  'instance_of|P31__wikidata': 'literary work|Q7725634',
#  'isbn': '0824043758',
#  'isbns': ['9780824043759', '9780824043759', '9780824043759'],
#  'label__wikidata': 'Ulysses',
#  'language': 'eng',
#  'language__txtlab': 'English',
#  'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#  'last_line|P3132__wikidata': 'I said yes I will Yes.',
#  'last_rights_update_date': 20161119,
#  'lcc': 'PR6019.O9U4 1984',
#  'lccn': '84004094',
#  'length__txtlab': '264170',
#  'libraries__chicago': '118',
#  'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#  'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#  'main_entity_of_page': ['https://catalog.hathitrust.org/Record/000249715',
#   'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#   'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#  'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#  'modernist_commons_id|P9365__wikidata': '15',
#  'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#  'name_first__markmark': 'James',
#  'name_last__markmark': 'Joyce',
#  'name_middle__markmark': 'Augustine Aloysius',
#  'narrative_location|P840__wikidata': ['Dublin|Q1761',
#   'James Joyce Tower and Museum|Q2062702',
#   'National Library of Ireland|Q1672830',
#   'Sandymount Strand|Q7417543',
#   'Glasnevin Cemetery|Q1263215',
#   "Freeman's Journal|Q5500969",
#   "Davy Byrne's pub|Q5242183",
#   'Dalkey|Q659895',
#   'Cabra (Dublin)|Q2088319',
#   'Grafton Street|Q135501',
#   "O'Connell Bridge|Q1766409",
#   "Nelson's Pillar|Q2350741",
#   'National Maternity Hospital, Dublin|Q13156901',
#   '#7 Eccles street|Q28601860'],
#  'nation__markmark': 'Irish',
#  'national_diet_library_id|P349__wikidata': '00971887',
#  'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#  'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#  'nationality__chicago': 'Irish',
#  'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#  'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#  'nnl_item_id|P3959__wikidata': '001210300',
#  'notes__markmark': 'serialized 1918-1920',
#  'num_vols': 6,
#  'num_words__markmark': '282576',
#  'number_of_parts_of_this_work|P2635__wikidata': {'amount': '+18',
#   'unit': 'http://www.wikidata.org/entity/Q1983062'},
#  'oclc': '10505634',
#  'oclc_work_id|P5331__wikidata': '395796',
#  'ocr_accuracy__markmark': '0.771848989298',
#  'open_library_id|P648__wikidata': 'OL86344W',
#  'page_count': 658,
#  'person__txtlab': 'first',
#  'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#  'pub_date': 1900,
#  'pub_place': 'New York (State)',
#  'pub_place_ld': {'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#   'name': 'New York (State)'},
#  'publ_city__chicago': 'Paris',
#  'publ_date__chicago': '1922',
#  'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#  'publishDate': '1900',
#  'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#  'publisher': 'Garland Pub.',
#  'publisher__chicago': 'Shakespeare & Co',
#  'publisher_ld': {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'Garland Pub.'},
#  'publisher|P123__wikidata': ['Shakespeare and Company|Q1503157',
#   'Sylvia Beach|Q265562'],
#  'race_ethnicity__chicago': 'Caucasian',
#  'recordURL': 'https://catalog.hathitrust.org/Record/000249715',
#  'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#  'significant_event|P793__wikidata': ['Bloomsday|Q804551',
#   'Obscenity trial of Ulysses in The Little Review|Q16153541',
#   'United States v. One Book Called Ulysses|Q2895062'],
#  'source__chicago': 'k',
#  'source_institution': 'MIU',
#  'source_institution_ld': {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'MIU'},
#  'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#  'title': 'Ulysses /',
#  'title__chicago': 'Ulysses',
#  'title__markmark': 'Ulysses',
#  'title__txtlab': 'Ulysses',
#  'title|P1476__wikidata': 'Ulysses',
#  'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#  'type': ['DataFeedItem', 'Book'],
#  'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#  'viaf_id|P214__wikidata': '174999739',
#  'what__wikidata': 'literary work',
#  'year__chicago': '1922',
#  'year__markmark': '1922',
#  'year__txtlab': '1922'}

# %%
thv=TextHathiVolume('htid/mdp.39015005917359', _corpus=C)
thv
# Out:
# TextHathiVolume(_hathi/htid/mdp.39015005917359)

# %%
with log: C.text('htid/mdp.39015005917359').query()
# Out:
# [18:32:36] lltk.corpus.corpus.text( <- id = htid/mdp.39015005917359, corpus = HathiCorpus(hathi) )
# [18:32:36] lltk.corpus.corpus.text( -> TextHathiVolume(_hathi/htid/mdp.39015005917359) )

# %%
thv.metadata()
# Out:
# {'id': 'htid/mdp.39015005917359',
#  'id__chicago': '00004881',
#  'id__hathi': 'htid/uc1.31822001992759',
#  'id__markmark': 'Joyce,_James.Ulysses',
#  'id__txtlab': 'EN_1922_Joyce,James_Ulysses_Novel',
#  'id__wikidata': 'Q6511',
#  'access_profile': 'google',
#  'access_rights': 'pd',
#  'ausstage_work_id|P8294__wikidata': '3970',
#  'auth_first__chicago': 'James',
#  'auth_id__chicago': 'A_01848',
#  'auth_last__chicago': 'Joyce',
#  'author__chicago': 'Joyce, James',
#  'author__markmark': 'Joyce, James Augustine Aloysius',
#  'author__txtlab': 'Joyce,James',
#  'author|P50__wikidata': 'James Joyce|Q6882',
#  'award_received|P166__wikidata': "Le Monde's 100 Books of the Century|Q40734",
#  'based_on|P144__wikidata': 'Odyssey|Q35160',
#  'biblioteca_nacional_de_espana_id|P950__wikidata': 'XX3383715',
#  'bibliotheque_nationale_de_france_id|P268__wikidata': '11943692j',
#  'bitraga_work_id|P6175__wikidata': ['5309', '4955'],
#  'book_id__chicago': '4881',
#  'bookbrainz_work_id|P7823__wikidata': 'fdcce91f-92e1-4e00-8045-e7187bd7ebe0',
#  'bookogs_work_id|P8211__wikidata': '405385',
#  'category': 'English literature',
#  'characters|P674__wikidata': ['Leopold Bloom|Q573988',
#   'Molly Bloom|Q2296791',
#   'Stephen Dedalus|Q543671',
#   'May Goulding Dedalus|Q16910626',
#   'Simon Dedalus|Q7518595',
#   'Milly Bloom|Q6860161',
#   'Buck Mulligan|Q4982905',
#   'Michael Cusack|Q1927217',
#   'George William Russell|Q366070',
#   'William Magee|Q18880357',
#   'Thomas William Lyster|Q1416892',
#   'Joseph Patrick Nannetti|Q1707785',
#   'Richard Irvine Best|Q7326690',
#   'David Sheehy|Q5239704',
#   'John Hooper|Q6239779',
#   'Tisdall Farrell|Q28575591',
#   'Haines|Q28601692',
#   'Martha Clifford|Q28602262',
#   'Garrett Deasy|Q16739979',
#   "C. P. M'Coy|Q28602472",
#   'Corny Kelleher (Ulysses character)|Q16910929',
#   'Jack Power (Ulysses character)|Q16919411',
#   'Martin Cunningham|Q16739992'],
#  'commons_category|P373__wikidata': 'Ulysses (James Joyce)',
#  'contributor': ['Joyce, James, 1882-1941',
#   'Melchior, Claus',
#   'Steppe, Wolfhard',
#   'Gabler, Hans Walter, 1938-'],
#  'contributor_ld': [{'id': 'http://www.viaf.org/viaf/44300643',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Joyce, James, 1882-1941'},
#   {'id': 'http://www.viaf.org/viaf/54210018',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Melchior, Claus'},
#   {'id': 'http://www.viaf.org/viaf/14785516',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Steppe, Wolfhard'},
#   {'id': 'http://www.viaf.org/viaf/108429204',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Gabler, Hans Walter, 1938-'}],
#  'copyright_status|P6216__wikidata': ['public domain|Q19652',
#   'public domain|Q19652'],
#  'corpus__markmark': 'MarkMark',
#  'country_of_origin|P495__wikidata': ['France|Q142',
#   'United States of America|Q30',
#   'French Third Republic|Q70802',
#   'United Kingdom of Great Britain and Ireland|Q174193'],
#  'date__txtlab': '1922',
#  'date_b__chicago': '1882',
#  'date_created': 20200209,
#  'date_d__chicago': '1941',
#  'default_page_section': 'body',
#  'derivative_work|P4969__wikidata': ['Ulysses|Q820061', 'Bloom|Q4928147'],
#  'dewey_decimal_classification_(works_and_editions)|P8359__wikidata': '823.912',
#  'dob__markmark': '1882.0',
#  'dod__markmark': '1941.0',
#  'education__chicago': 'U Coll Dublin',
#  'encyclopaedia_britannica_online_id|P1417__wikidata': 'topic/Ulysses-novel-by-Joyce',
#  'encyclopaedia_universalis_id|P3219__wikidata': 'ulysse-james-joyce',
#  'enumeration_chronology': 'v.3',
#  'feature_schema_version': 'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#  'filename__chicago': '00004881.txt',
#  'first_line|P1922__wikidata': 'Stately, plump Buck Mulligan came from the stairhead, bearing a bowl of lather on which a mirror and a razor lay crossed.',
#  'followed_by|P156__wikidata': 'Finnegans Wake|Q6507',
#  'follows|P155__wikidata': 'A Portrait of the Artist as a Young Man|Q465360',
#  'form_of_creative_work|P7937__wikidata': 'novel|Q8261',
#  'freebase_id|P646__wikidata': '/m/0f3dt',
#  'full_work_available_at_url|P953__wikidata': 'https://archive.org/stream/ulysses04300gut/ulyss12.txt',
#  'gender__chicago': 'M',
#  'gender__markmark': 'M',
#  'gender__txtlab': 'male',
#  'genre': ['document (computer)', 'bibliography', 'fiction'],
#  'genre__chicago': 'SOC',
#  'genre_ld': ['http://id.loc.gov/vocabulary/marcgt/doc',
#   'http://id.loc.gov/vocabulary/marcgt/bib',
#   'http://id.loc.gov/vocabulary/marcgt/fic'],
#  'genre|P136__wikidata': ['modernist literature|Q971480',
#   'experimental literature|Q1384425',
#   'literary fiction|Q6647667',
#   'metafiction|Q531067',
#   'serialized fiction|Q1347298',
#   'autobiography|Q4184'],
#  'geography__chicago': 'Dublin, Ireland; Trieste, Italy; Zurich, Switzerland; Paris, France',
#  'gnd_id|P227__wikidata': '4099246-9',
#  'gran_enciclopedia_catalana_id|P1296__wikidata': '0068263',
#  'handle_url': 'http://hdl.handle.net/2027/uc1.31822001992759',
#  'has_edition_or_translation|P747__wikidata': ['Ulysses (2004 German translation)|Q15996608',
#   'Ulysses|Q19020726',
#   'Ulysses (1986)|Q28599480',
#   'Ulysses (1932)|Q28599496',
#   'Ulysses (1934)|Q28599520',
#   'Ulysses (1936)|Q28599521',
#   'Ulysses (1960)|Q28599523',
#   'Ulysses (1961)|Q28599525',
#   'Ulysses (1984)|Q28599531',
#   'Ulysses (2004)|Q28599849',
#   'Iliada|Q33182025',
#   'Ulysses (1935)|Q104191512'],
#  'has_part_or_parts|P527__wikidata': ['Telemachus|Q28601581',
#   'Nestor|Q28601624',
#   'Proteus|Q28601724',
#   'Calypso|Q28601800',
#   'Lotus-eaters|Q28602222',
#   'Hades|Q28602572',
#   'Aeolus|Q28602745',
#   'Lestrygonians|Q28647765',
#   'Scylla and Charybdis|Q28657069',
#   'Wandering Rocks|Q28709812',
#   'Sirens|Q56103204',
#   'Cyclops|Q56103151',
#   'Nausikaa|Q56103127',
#   'Oxen of the Sun|Q56103091',
#   'Circe|Q56103050',
#   'Eumaeus|Q56103019',
#   'Ithaca|Q56102932',
#   'Penelope|Q38138028'],
#  'htid': 'uc1.31822001992759',
#  'htids': ['uc1.31822006892251',
#   'mdp.39015005917359',
#   'uc1.31822001992726',
#   'mdp.39015005917367',
#   'uc1.31822001992759',
#   'mdp.39015005917375'],
#  'id_orig__txtlab': '296',
#  'idref_id|P269__wikidata': '027383113',
#  'image|P18__wikidata': 'UlyssesCover.jpg',
#  'inception|P571__wikidata': '+1914-00-00T00:00:00Z',
#  'inspired_by|P941__wikidata': 'Odyssey|Q35160',
#  'instance_of|P31__wikidata': 'literary work|Q7725634',
#  'isbn': '0824043758',
#  'isbns': ['9780824043759', '9780824043759', '9780824043759'],
#  'label__wikidata': 'Ulysses',
#  'language': 'eng',
#  'language__txtlab': 'English',
#  'language_of_work_or_name|P407__wikidata': 'English|Q1860',
#  'last_line|P3132__wikidata': 'I said yes I will Yes.',
#  'last_rights_update_date': 20171203,
#  'lcc': 'PR6019.O9U4 1984',
#  'lccn': '84004094',
#  'length__txtlab': '264170',
#  'libraries__chicago': '118',
#  'library_of_congress_authority_id|P244__wikidata': 'n92029109',
#  'librarything_work_id|P1085__wikidata': ['21004298', '21004302'],
#  'main_entity_of_page': ['https://catalog.hathitrust.org/Record/000249715',
#   'http://catalog.hathitrust.org/api/volumes/brief/oclc/10505634.json',
#   'http://catalog.hathitrust.org/api/volumes/full/oclc/10505634.json'],
#  'metadata_schema_version': 'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#  'modernist_commons_id|P9365__wikidata': '15',
#  'musicbrainz_work_id|P435__wikidata': '67e71930-7053-448a-8326-6917f683a4ea',
#  'name_first__markmark': 'James',
#  'name_last__markmark': 'Joyce',
#  'name_middle__markmark': 'Augustine Aloysius',
#  'narrative_location|P840__wikidata': ['Dublin|Q1761',
#   'James Joyce Tower and Museum|Q2062702',
#   'National Library of Ireland|Q1672830',
#   'Sandymount Strand|Q7417543',
#   'Glasnevin Cemetery|Q1263215',
#   "Freeman's Journal|Q5500969",
#   "Davy Byrne's pub|Q5242183",
#   'Dalkey|Q659895',
#   'Cabra (Dublin)|Q2088319',
#   'Grafton Street|Q135501',
#   "O'Connell Bridge|Q1766409",
#   "Nelson's Pillar|Q2350741",
#   'National Maternity Hospital, Dublin|Q13156901',
#   '#7 Eccles street|Q28601860'],
#  'nation__markmark': 'Irish',
#  'national_diet_library_id|P349__wikidata': '00971887',
#  'national_library_of_israel_id_(old)|P949__wikidata': '001787167',
#  'national_library_of_israel_j9u_id|P8189__wikidata': '987007590322605171',
#  'nationality__chicago': 'Irish',
#  'ne.se_id|P3222__wikidata': 'odysseus-(joyce)',
#  'nkcr_aut_id|P691__wikidata': 'aun2006373019',
#  'nnl_item_id|P3959__wikidata': '001210300',
#  'notes__markmark': 'serialized 1918-1920',
#  'num_vols': 6,
#  'num_words__markmark': '282576',
#  'number_of_parts_of_this_work|P2635__wikidata': {'amount': '+18',
#   'unit': 'http://www.wikidata.org/entity/Q1983062'},
#  'oclc': '10505634',
#  'oclc_work_id|P5331__wikidata': '395796',
#  'ocr_accuracy__markmark': '0.771848989298',
#  'open_library_id|P648__wikidata': 'OL86344W',
#  'page_count': 600,
#  'person__txtlab': 'first',
#  'project_gutenberg_ebook_id|P2034__wikidata': '4300',
#  'pub_date': 1900,
#  'pub_place': 'New York (State)',
#  'pub_place_ld': {'id': 'http://id.loc.gov/vocabulary/countries/nyu',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#   'name': 'New York (State)'},
#  'publ_city__chicago': 'Paris',
#  'publ_date__chicago': '1922',
#  'publication_date|P577__wikidata': '+1922-02-02T00:00:00Z',
#  'publishDate': '1900',
#  'published_in|P1433__wikidata': 'The Little Review|Q17113018',
#  'publisher': 'Garland Pub.',
#  'publisher__chicago': 'Shakespeare & Co',
#  'publisher_ld': {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Garland%20Pub.',
#   'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'Garland Pub.'},
#  'publisher|P123__wikidata': ['Shakespeare and Company|Q1503157',
#   'Sylvia Beach|Q265562'],
#  'race_ethnicity__chicago': 'Caucasian',
#  'recordURL': 'https://catalog.hathitrust.org/Record/000249715',
#  'set_in_period|P2408__wikidata': 'June 1904|Q13066091',
#  'significant_event|P793__wikidata': ['Bloomsday|Q804551',
#   'Obscenity trial of Ulysses in The Little Review|Q16153541',
#   'United States v. One Book Called Ulysses|Q2895062'],
#  'source__chicago': 'k',
#  'source_institution': 'UCSD',
#  'source_institution_ld': {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#   'name': 'UCSD'},
#  'svkkl_authority_id|P9322__wikidata': '0377445-Joyce-James-18821941',
#  'title': 'Ulysses /',
#  'title__chicago': 'Ulysses',
#  'title__markmark': 'Ulysses',
#  'title__txtlab': 'Ulysses',
#  'title|P1476__wikidata': 'Ulysses',
#  'topics_main_category|P910__wikidata': 'Category:Ulysses (novel)|Q8857597',
#  'type': ['DataFeedItem', 'Book'],
#  'type_of_resource': 'http://id.loc.gov/ontologies/bibframe/Text',
#  'viaf_id|P214__wikidata': '174999739',
#  'what__wikidata': 'literary work',
#  'year__chicago': '1922',
#  'year__markmark': '1922',
#  'year__txtlab': '1922'}

# %%
thv.author
# Out:
# 'Joyce, James, 1882-1941'

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/lltk/corpus/hathi/hathi.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/lltk/corpus/hathi/hathi.ipynb#ch0000014?line=0'>1</a> stop
#
# NameError: name 'stop' is not defined

# %%
from hathitrust_api import BibAPI
bib = BibAPI()

# %%
bib.get_single_record_json('htid', 'mdp.39015005917359')

# %%
htid='mdp.39015005917359'
htid='hvd.32044013656053'
from htrc_features import Volume
vol = Volume(htid)

# %%
p,meta=to_params_meta(vol.__dict__)

# %%
# Out:
# False

# %%
[(k,v,type(v)) for k,v in meta.items()]
# Out:
# [('id_resolver',
#   <htrc_features.caching.make_fallback_resolver.<locals>.FallbackResolver at 0x29a81b1c0>,
#   htrc_features.caching.make_fallback_resolver.<locals>.FallbackResolver),
#  ('default_page_section', 'body', str),
#  ('parser',
#   <htrc_features.parsers.JsonFileHandler at 0x29a8862b0>,
#   htrc_features.parsers.JsonFileHandler),
#  ('args', {}, dict),
#  ('id', 'hvd.32044013656053', str),
#  ('metadata_schema_version',
#   'https://schemas.hathitrust.org/EF_Schema_MetadataSubSchema_v_3.0',
#   str),
#  ('enumeration_chronology', 'v.1', str),
#  ('type_of_resource', 'http://id.loc.gov/ontologies/bibframe/Text', str),
#  ('title', 'Pride and prejudice.', str),
#  ('date_created', 20200209, int),
#  ('pub_date', 1903, int),
#  ('language', 'eng', str),
#  ('access_profile', 'google', str),
#  ('isbn', None, NoneType),
#  ('issn', None, NoneType),
#  ('lccn', None, NoneType),
#  ('oclc', '226464547', str),
#  ('page_count', 298, int),
#  ('feature_schema_version',
#   'https://schemas.hathitrust.org/EF_Schema_FeaturesSubSchema_v_3.0',
#   str),
#  ('access_rights', 'pd', str),
#  ('alternate_title', None, NoneType),
#  ('category', None, NoneType),
#  ('genre_ld', 'http://id.loc.gov/vocabulary/marcgt/doc', str),
#  ('genre', ['document (computer)'], list),
#  ('contributor_ld',
#   {'id': 'http://www.viaf.org/viaf/102333412',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Person',
#    'name': 'Austen, Jane, 1775-1817.'},
#   dict),
#  ('contributor', 'Austen, Jane, 1775-1817.', str),
#  ('handle_url', 'http://hdl.handle.net/2027/hvd.32044013656053', str),
#  ('source_institution_ld',
#   {'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#    'name': 'HVD'},
#   dict),
#  ('source_institution', 'HVD', str),
#  ('lcc', None, NoneType),
#  ('type', ['DataFeedItem', 'Book'], list),
#  ('is_part_of', None, NoneType),
#  ('last_rights_update_date', 20180620, int),
#  ('pub_place_ld',
#   {'id': 'http://id.loc.gov/vocabulary/countries/mau',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Place',
#    'name': 'Massachusetts'},
#   dict),
#  ('pub_place', 'Massachusetts', str),
#  ('main_entity_of_page',
#   ['https://catalog.hathitrust.org/Record/100323335',
#    'http://catalog.hathitrust.org/api/volumes/brief/oclc/226464547.json',
#    'http://catalog.hathitrust.org/api/volumes/full/oclc/226464547.json'],
#   list),
#  ('publisher_ld',
#   {'id': 'http://catalogdata.library.illinois.edu/lod/entities/ProvisionActivityAgent/ht/Little,%20Brown',
#    'type': 'http://id.loc.gov/ontologies/bibframe/Organization',
#    'name': 'Little, Brown'},
#   dict),
#  ('publisher', 'Little, Brown', str)]
