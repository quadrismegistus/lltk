# %%
import sys; sys.path.insert(0,'/Users/ryan/github/yapmap')
import sys; sys.path.insert(0,os.path.abspath('../../..'))
from hathi import *
from lltk.model.networks import *
# !open {log.fn}

# %%
with log:
    t=Text(get_idx(), title='Emma', author='Jane Austen')
    t.init(remote=True)
# Out:
# [16:10:30] lltk.text.text.Text( <- id = T30903, kwargs = {'title': 'Emma', 'author': 'Jane Austen'}) )
# [16:10:30] lltk.corpus.corpus.Corpus( <- id = None )
# [16:10:30] lltk.corpus.corpus.__init__( BaseCorpus(None) )
# [16:10:30] lltk.corpus.corpus.Corpus( -> BaseCorpus(tmp) )
# [16:10:30] lltk.text.text.Text( <- addr = _tmp/T30903 )
# [16:10:30] lltk.corpus.corpus.Corpus( <- id = tmp )
# [16:10:30] lltk.corpus.corpus.Corpus( -> BaseCorpus(tmp) )
# [16:10:30] lltk.corpus.corpus.text( <- {'title': 'Emma', 'author': 'Jane Austen'} )
# [16:10:30] lltk.corpus.corpus.text( <- id = T30903, corpus = BaseCorpus(tmp), kwargs = {'title': 'Emma', 'author': 'Jane Austen'}) )
# [16:10:30] lltk.corpus.corpus.get_text( <- id = T30903 )
# [16:10:30] lltk.corpus.corpus.get_text( -> ? )
# [16:10:30] lltk.corpus.corpus.init_text( ... )
# [16:10:30] lltk.corpus.corpus.init_text( <- id = T30903, corpus = BaseCorpus(tmp), kwargs = {'title': 'Emma', 'author': 'Jane Austen'}) )
# ...

# %%
draw_nx(t.matchgraph())

# %% [markdown]
# t.

# %%
with log: Corpus('goodreads').text_from(t)
# Out:
# [16:10:34] lltk.corpus.corpus.Corpus( <- id = goodreads )
# [16:10:34] lltk.corpus.corpus.Corpus( -> GoodreadsCorpus(goodreads) )
# [16:10:34] goodreads.texts_from( 0 192553445 )
# [16:10:34] goodreads.texts_from( { 'aggregateRating': '',
#   'author': '',
#   'id': ']',
#   'page_url': ']',
#   'reviewers': '',
#   'search_type': 'books',
#   'title': ''} )

# %%
t.isbn_
# Out:
# {'isbn': {(_hathi/htid/mdp.39015002201252): '0192553445',
#   (_hathi/htrn/000354247): '0192553445',
#   (_isbn/192553445): '192553445'}}

# %%
t.qstr
# Out:
# 'Emma Austen'
