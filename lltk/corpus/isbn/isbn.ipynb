# %%
import sys; sys.path.insert(0,'/Users/ryan/github/yapmap')
import sys; sys.path.insert(0,os.path.abspath('../../..'))
from lltk import *
# log.show()
# log.verbose=0

# %%
# t=Text('_isbn/089966606X')
# t=Text('_isbn/140034994')
t=Text('_isbn/9780899666068')
# t.clear()

# %%
with log: x=t._meta
x
# Out:
# {'id': '9780899666068',
#  '_addr': '_isbn/9780899666068',
#  '_corpus': 'isbn',
#  'accessInfo': {'country': 'GB',
#   'viewability': 'NO_PAGES',
#   'embeddable': False,
#   'publicDomain': False,
#   'textToSpeechPermission': 'ALLOWED',
#   'epub': {'isAvailable': False},
#   'pdf': {'isAvailable': False},
#   'webReaderLink': 'http://play.google.com/books/reader?id=GNhaAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#   'accessViewStatus': 'NONE',
#   'quoteSharingAllowed': False},
#  'authors': 'Henry James',
#  'averageRating': 3.5,
#  'canonicalVolumeLink': 'https://books.google.com/books/about/The_Ambassadors.html?hl=&id=GNhaAAAAMAAJ',
#  'categories': 'Fiction',
#  'contentVersion': '0.2.1.0.preview.0',
# ...

# %%
with log: x=t.init(remote=True)._meta
x
# Out:
# [09:40:00] lltk.text.text.init( Init metadata: TextISBN(_isbn/9780899666068), kwargs = {} )
# [09:40:00] isbn.query( 9780899666068 )
# [09:40:00] isbn.query( https://www.googleapis.com/books/v1/volumes?q=isbn:9780899666068 )
# [09:40:00] isbn.query( None )
# [09:40:00] isbn.query( ? 9780899666068 )
# [09:40:01] isbn.query( 3 keys in json: { 'items': [ { 'accessInfo': { 'accessViewStatus': 'NONE',
#                                'country': 'GB',
#                                'embeddable': False,
#                                'epub': {'isAvailable': False},
#                                'pdf': {'isAvailable': False},
#                                'publicDomain': False,
#                                'quoteSharingAllowed': False,
#                                'textToSpeechPermission': 'ALLOWED',
#                                'viewability': 'NO_PAGES',
# ...

# %%
with log: x=t.query()
x
# Out:
# [09:37:12] isbn.query( 089966606X )
# [09:37:12] isbn.query( https://www.googleapis.com/books/v1/volumes?q=isbn:089966606X )
# ...

# %%
STOPX
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/lltk/corpus/isbn/isbn.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/lltk/corpus/isbn/isbn.ipynb#ch0000005?line=0'>1</a> STOPX
#
# NameError: name 'STOPX' is not defined

# %%
with log:
    t = Text(title='Dalloway', author='Woolf')
    t.init(remote=True)
    d=t.meta
d
# Out:
# [09:24:20] lltk.text.text.Text( <- kwargs = {'title': 'Dalloway', 'author': 'Woolf'}) )
# [09:24:20] lltk.corpus.corpus.Corpus( <- id = None )
# [09:24:20] lltk.corpus.corpus.__init__( BaseCorpus(None) )
# [09:24:20] lltk.corpus.corpus.Corpus( -> BaseCorpus(tmp) )
# [09:24:20] lltk.text.text.Text( <- addr = _tmp/author=Woolf/title=Dalloway )
# [09:24:20] lltk.corpus.corpus.Corpus( <- id = tmp )
# [09:24:20] lltk.corpus.corpus.Corpus( -> BaseCorpus(tmp) )
# [09:24:20] lltk.corpus.corpus.text( <- {'title': 'Dalloway', 'author': 'Woolf'} )
# [09:24:20] lltk.corpus.corpus.text( <- id = author=Woolf/title=Dalloway, corpus = BaseCorpus(tmp), kwargs = {'title': 'Dalloway', 'author': 'Woolf'}) )
# [09:24:20] lltk.corpus.corpus.get_text( <- id = author=Woolf/title=Dalloway )
# [09:24:20] lltk.corpus.corpus.get_text( -> ? )
# [09:24:20] lltk.corpus.corpus.init_text( ... )
# ...

# %%
t.goodreads
# Out:
# '841320'

# %%
for isbn in t.isbn_l: print(isbn)
# Out:
# 1509843310
# 9781509843312
# 9780151009985
# 0151009988
# 9780156628709
# 0156628708

# %%
for src in t.sources:
    print(src, list(src.get_remote_sources()),'',sep='\n')
# Out:
# TextHathiVolume(_hathi/htid/mdp.39015013962207)
# []
#
# TextHathiVolume(_hathi/htid/ucbk.ark:/28722/h2445hc94)
# []
#
# TextHathiVolume(_hathi/htid/ucbk.ark:/28722/h25h7bw1s)
# []
#
# TextHathiRecord(_hathi/htrn/000265891)
# []
#
# TextWikidataClass(_wikidata/Q752584)
# []
#
# TextWorldcat(_worldcat/20932825)
# []
#
# TextWorldcat(_worldcat/464804453)
# []

# %%
random.choice(t.sources)._meta
# Out:
# {'id': '219776569', '_addr': '_worldcat/219776569', '_corpus': 'worldcat'}

# %%
C = Corpus('isbn')
C
# Out:
# IsbnCorpus(isbn)

# %%
with log: tw=C.text_from(t)
tw
# Out:
# [21:03:20] isbn.texts_from( BaseText(_tmp/author=Woolf/title=Dalloway) )
# [21:03:20] lltk.text.text.metadata( ... )
# [21:03:20] lltk.text.text.metadata_initial( ... )
# [21:03:20] lltk.text.text.metadata_from_cache( ... )
# [21:03:20] lltk.text.text.init_cache( ... )
# [21:03:20] lltk.text.text.metadata_from_sources( ... )
# [21:03:20] lltk.text.text.get_sources( ... )
# [21:03:20] lltk.text.text.get_matches( ... )
# [21:03:20] lltk.text.text.metadata( ... )
# [21:03:20] lltk.text.text.metadata_initial( ... )
# [21:03:20] lltk.text.text.metadata_from_cache( ... )
# [21:03:20] lltk.text.text.init_cache( ... )
# [21:03:20] lltk.text.text.metadata( ... )
# [21:03:20] lltk.text.text.metadata_initial( ... )
# [21:03:20] lltk.text.text.metadata_from_cache( ... )
# [21:03:20] lltk.text.text.init_cache( ... )
# [21:03:20] lltk.text.text.metadata( ... )
# [21:03:20] lltk.text.text.metadata_initial( ... )
# [21:03:20] lltk.text.text.metadata_from_cache( ... )
# ...

# %%
t.isbn
# Out:
# ['1509843310',
#  '9781509843312',
#  '9780151009985',
#  '0151009988',
#  '9780156628709',
#  '0156628708']

# %%
text=t

# %%
l=[]
isbns,isbn=text.isbns,text.isbn
if isbn and type(isbn)==str: l+=[isbn]
if isbns and type(isbns)==list: l+=isbns
text.isbn
# Out:
# ['1509843310',
#  '9781509843312',
#  '9780151009985',
#  '0151009988',
#  '9780156628709',
#  '0156628708']
