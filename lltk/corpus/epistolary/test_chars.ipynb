# %% [markdown]
# # Character network

# %%
import sys; sys.path.insert(0,'/Users/ryan/github/lltk')
from epistolary import *
from lltk.model.characters import *
setup_log(to_screen=False)

# %%
t = get_canon('clarissa')
CS = t.characters()
g=CS.graph(t=250)
draw_nx(g)

# %%
odir=os.path.join(CS.path, 'imgs')
fn,fig=draw_nx_dynamic(CS.graph_iter(), color_by='t_new', odir_imgs=odir, fps=10, force=False)
fig
# Out:
# Iterating over event: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 527/527 [00:48<00:00, 10.82it/s]
# Making movie (fig.dynamic_graph.mp4) [527)]...
#     <video width=666 controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %%
g = CS.graph()
print(g)

# %%
draw_nx(g, color_by='t_new')

# %%
# fn,fig=draw_nx_dynamic(CS.graph_iter(), final_g=CS.graph(), fps=5, color_by='t_new')
# fig
