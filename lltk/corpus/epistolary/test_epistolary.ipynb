# %% [markdown]
# # Epistolary

# %%
import os,sys; sys.path.insert(0,os.path.abspath('../../..'))
from epistolary import *

# %%
C=Epistolary()
C.meta
# Out:
# [10:55:00] lltk.corpus.corpus.metadata():256: Generating metadata dataframe
# [10:55:00] lltk.corpus.corpus.init():239: Initializing from metadata: [Epistolary](epistolary)
# [10:55:00] lltk.corpus.corpus.init():239: Initializing from metadata: [Chadwyck](chadwyck)
# Iterating over texts: 100%|██████████| 5/5 [00:00<00:00, 6112.36it/s]
# [10:55:00] lltk.corpus.corpus.metadata():269: Returning dataframe of (5, 12) dimensions
#                                                  testing  \
# id
# Eighteenth-Century_Fiction/richards.02                 x
# _chadwyck/Eighteenth-Century_Fiction/richards.04       y
# _chadwyck/Eighteenth-Century_Fiction/burney.01
# _chadwyck/Eighteenth-Century_Fiction/richards.01
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                                          author  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  Richardson, Samuel, 1689-1761
# _chadwyck/Eighteenth-Century_Fiction/burney.01         Burney, Fanny, 1752-1840
# _chadwyck/Eighteenth-Century_Fiction/richards.01  Richardson, Samuel, 1689-1761
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                                       title  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04              Pamela (1741)
# _chadwyck/Eighteenth-Century_Fiction/burney.01               Evelina (1778)
# _chadwyck/Eighteenth-Century_Fiction/richards.01  Clarissa (1st ed.) (1748)
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                   year       idref  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  1741  Z200045357
# _chadwyck/Eighteenth-Century_Fiction/burney.01    1778  Z200000830
# _chadwyck/Eighteenth-Century_Fiction/richards.01  1748  Z200044053
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                                                                 pub  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  Printed for C. Rivington, in St. Paul's Church...
# _chadwyck/Eighteenth-Century_Fiction/burney.01                       Printed for T. Lowndes, [etc.]
# _chadwyck/Eighteenth-Century_Fiction/richards.01                  Printed for S. Richardson: [etc.]
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                   type    name   nation  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  BOOK  Vol. 1  British
# _chadwyck/Eighteenth-Century_Fiction/burney.01    BOOK  Vol. 1  British
# _chadwyck/Eighteenth-Century_Fiction/richards.01  BOOK  Vol. 1  British
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                    medium  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  Fiction
# _chadwyck/Eighteenth-Century_Fiction/burney.01    Fiction
# _chadwyck/Eighteenth-Century_Fiction/richards.01  Fiction
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                                    subcorpus  \
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  Eighteenth-Century_Fiction
# _chadwyck/Eighteenth-Century_Fiction/burney.01    Eighteenth-Century_Fiction
# _chadwyck/Eighteenth-Century_Fiction/richards.01  Eighteenth-Century_Fiction
# _chadwyck/Eighteenth-Century_Fiction/haywood.02
#
#                                                                                       fn_raw
# id
# Eighteenth-Century_Fiction/richards.02
# _chadwyck/Eighteenth-Century_Fiction/richards.04  Eighteenth-Century_Fiction/richards.04.new
# _chadwyck/Eighteenth-Century_Fiction/burney.01      Eighteenth-Century_Fiction/burney.01.new
# _chadwyck/Eighteenth-Century_Fiction/richards.01  Eighteenth-Century_Fiction/richards.01.new
# _chadwyck/Eighteenth-Century_Fiction/haywood.02

# %%
clarissa = C.textd['_chadwyck/Eighteenth-Century_Fiction/richards.01']
clarissa_letters = clarissa.sections
clarissa_letters.meta
# Out:
# [10:55:01] lltk.corpus.corpus.metadata():256: Generating metadata dataframe
# [10:55:01] lltk.corpus.corpus.init():239: Initializing from metadata: [SectionCorpusLetterChadwyck](_chadwyck/EighteenthCentury_Fiction/richards01/sections)
# Iterating over texts: 100%|██████████| 625/625 [00:00<00:00, 1019222.40it/s]
# [10:55:03] lltk.corpus.corpus.metadata():269: Returning dataframe of (625, 20) dimensions
#           id_orig  vol_i  letter_i  letter_ii  num_enclosed depth_enclosed  \
# id
# L001a  Z300044056      1         1          0             0              0
# L002a  Z300044057      1         2          0             0              0
# L003a  Z300044058      1         3          0             0              0
# L004a  Z300044059      1         4          0             0              0
# L005a  Z300044060      1         5          0             0              0
# ...           ...    ...       ...        ...           ...            ...
# L525b  Z300044595      7       525          1             2              0
# L525c  Z300044595      7       525          2             0              1
# L525d  Z300044595      7       525          3             0              1
# L526a  Z300044596      7       526          0             0              0
# L527a  Z300044597      7       527          0             0              0
#
#             txt_head                                          txt_front  \
# id
# L001a      LETTER I.          Miss Anna Howe, To Miss Clarissa Harlowe.
# L002a     LETTER II.               Miss Clarissa Harlowe, To Miss Howe.
# L003a    LETTER III.               Miss Clarissa Harlowe, To Miss Howe.
# L004a     LETTER IV.               Miss Clarissa Harlowe, To Miss Howe.
# L005a      LETTER V.               Miss Clarissa Harlowe, To Miss Howe.
# ...              ...                                                ...
# L525b    LETTER CXI.    Mr. Lovelace, To John Belford, Esq; | * * | * *
# L525c
# L525d
# L526a   LETTER CXII.                Mr. Lovelace, To John Belford, Esq;
# L527a  LETTER CXIII.  Translation of a Letter from F. J. De la Tour....
#
#                                                txt_start  \
# id
# L001a  Jan. 10.  I am extremely concerned, my dearest...
# L002a  Harlowe-Place, Jan. 13.  How you oppress me, m...
# L003a  Jan. 13, 14.  And thus, as Mr. Lovelace though...
# L004a  This, my dear, was the situation Mr. Lovelace ...
# L005a  Jan. 20.  I have been hinder'd from prosecutin...
# ...                                                  ...
# L525b  Lintz, Nov. 28. ‚™Ü‚™ÜDec. 9.  I am now on my ...
# L525c  Munich, Nov. 21. ‚™Ü‚™ÜDec. 2.  Sir, Your lett...
# L525d  Vienna, Nov. 25. ‚™Ü‚™ÜDec. 6.  Sir, I have th...
# L526a  Trent, Dec. 3 - 14.  To-morrow is to be the Da...
# L527a  Trent, December 18. N.S.  Sir, I have melancho...
#
#                                                  txt_end  \
# id
# L001a  s and directresses: for your mamma, admirably ...
# L002a  denial: Yet gave him reason to think, that she...
# L003a  , what a visible Struggle it cost him to chang...
# L004a  ll not be taken as any, since my son James can...
# L005a  imes -- Indeed he is not dutiful. -- But, poss...
# ...                                                  ...
# L525b  out of my breast with my own hands, were it ca...
# L525c  s to pursue.  But being disappointed in my hop...
# L525d  Vienna, Nov. 25. ‚™Ü‚™ÜDec. 6.  Sir, I have th...
# L526a   weapon was as good as another throughout all ...
# L527a  a seeming ejaculation, he spoke inwardly so as...
#
#                   sender_tok              recip_tok  \
# id
# L001a         Miss Anna Howe  Miss Clarissa Harlowe
# L002a  Miss Clarissa Harlowe              Miss Howe
# L003a  Miss Clarissa Harlowe              Miss Howe
# L004a  Miss Clarissa Harlowe              Miss Howe
# L005a  Miss Clarissa Harlowe              Miss Howe
# ...                      ...                    ...
# L525b           Mr. Lovelace           John Belford
# L525c                      ?                      ?
# L525d                      ?                      ?
# L526a           Mr. Lovelace           John Belford
# L527a       F. J. De la Tour           John Belford
#
#                            date_ner            date_time  \
# id
# L001a                       Jan. 10  2022-01-10 00:00:00
# L002a                       Jan. 13  2022-01-13 00:00:00
# L003a                  Jan. 13 | 14  2014-01-13 00:00:00
# L004a
# L005a                       Jan. 20  2022-01-20 00:00:00
# ...                             ...                  ...
# L525b              Nov. 28 | Dec. 9                 None
# L525c  Nov. 21 | Dec. 2 | four days                 None
# L525d              Nov. 25 | Dec. 6                 None
# L526a         Dec. 3 - 14 | the Day                 None
# L527a           2022-12-18 00:00:00  2022-12-18 00:00:00
#
#                                date num_words id_parent  \
# id
# L001a                       Jan. 10      1073
# L002a                       Jan. 13      2129
# L003a                    Jan. 13-14      2597
# L004a                                    3445
# L005a                       Jan. 20      1044
# ...                             ...       ...       ...
# L525b              Nov. 28 | Dec. 9      1844
# L525c  Nov. 21 | Dec. 2 | four days       248     L525b
# L525d              Nov. 25 | Dec. 6       117     L525b
# L526a         Dec. 3 - 14 | the Day       953
# L527a           2022-12-18 00:00:00      1220
#
#                             place notes                   place_ner
# id
# L001a
# L002a               Harlowe-Place                     Harlowe-Place
# L003a               Harlowe-Place
# L004a               Harlowe-Place                          Scotland
# L005a               Harlowe-Place
# ...                           ...   ...                         ...
# L525b                       Trent                             Trent
# L525c           Munich | Florence                 Munich | Florence
# L525d                      Vienna                            Vienna
# L526a
# L527a  Esq | Soho-Square | London        Esq | Soho-Square | London
#
# [625 rows x 20 columns]

# %%
pd.to_numeric(clarissa_letters.meta.num_words).sum(), clarissa_letters.length
# Out:
# (846924, 864724)

# %%
# clarissa_letters.meta.groupby('sender_tok').num_words.sum().sort_values(ascending=False).head(10)
# clarissa_letters.meta.groupby('recip_tok').num_words.sum().sort_values(ascending=False).head(10)

# %% [markdown]
# ## Pamela

# %%
# pamela = C.textd['_chadwyck/Eighteenth-Century_Fiction/richards.04']
# pamela_letters = pamela.sections
# pamela_letters.meta

# %%
# pd.to_numeric(pamela_letters.meta.num_words).sum(), pamela.length

# %% [markdown]
# ## Evelina

# %%
evelina = C.textd['_chadwyck/Eighteenth-Century_Fiction/burney.01']
evelina_letters = evelina.sections
evelina_letters.meta
# Out:
# [10:51:08] lltk.corpus.corpus.metadata():251: Generating metadata dataframe
# [10:51:08] lltk.corpus.corpus.init():234: Initializing from metadata: [SectionCorpusLetterChadwyck](_chadwyck/EighteenthCentury_Fiction/burney01/sections)
# Iterating over texts: 100%|██████████| 91/91 [00:00<00:00, 613636.12it/s]
# [10:51:08] lltk.corpus.corpus.metadata():264: Returning dataframe of (91, 17) dimensions
#           id_orig  vol_i  letter_i  letter_ii  num_enclosed  depth_enclosed  \
# id
# L001a  Z300000836      1         1          0             0               0
# L002a  Z300000837      1         2          0             0               0
# L003a  Z300000838      1         3          0             0               0
# L004a  Z300000839      1         4          0             0               0
# L005a  Z300000840      1         5          0             0               0
# ...           ...    ...       ...        ...           ...             ...
# L081c  Z300000920      3        81          2             0               1
# L081d  Z300000920      3        81          3             0               1
# L082a  Z300000921      3        82          0             0               0
# L083a  Z300000922      3        83          0             0               0
# L084a  Z300000923      3        84          0             0               0
#
#             txt_head                                          txt_front  \
# id
# L001a      LETTER I.               Lady Howard to the Rev. Mr. Villars.
# L002a     LETTER II.                        Mr. Villars to Lady Howard.
# L003a    LETTER III.  [Written some months after the last.]  Lady Ho...
# L004a     LETTER IV.                        Mr. Villars to Lady Howard.
# L005a      LETTER V.                        Mr. Villars to Lady Howard.
# ...              ...                                                ...
# L081c                                                  To Miss Anville.
# L081d                                        To Sir Clement Willoughby.
# L082a    LETTER XXI.                           Evelina in continuation.
# L083a   LETTER XXII.                            Mr. Villars to Evelina.
# L084a  LETTER XXIII.                   Evelina to the Rev. Mr. Villars.
#
#                                                txt_start  \
# id
# L001a  Howard Grove.  Can there, my good Sir, be any ...
# L002a  Berry Hill, Dorsetshire.  Your Ladyship did bu...
# L003a  Howard Grove, March 8.  Dear and Rev. Sir, You...
# L004a  Berry Hill, March 12.  I am grieved, Madam, to...
# L005a  March 18.  Dear Madam, This letter will be del...
# ...                                                  ...
# L081c  I Have this moment received intelligence that ...
# L081d  Sir, The letter you have been pleased to addre...
# L082a  Clifton, October 13.  The time approaches now,...
# L083a  Every wish of my soul is now fulfilled  -- for...
# L084a  All is over, my dearest Sir, and the fate of y...
#
#                                                  txt_end   sender_tok  \
# id
# L001a  er peace and her reputation. Notwithstanding I...  Lady Howard
# L002a  , I fear my fortitude would have been unequal ...  Mr. Villars
# L003a  tly their wish to enlarge and enliven their pa...  Lady Howard
# L004a  et I have thought it necessary to let her be h...  Mr. Villars
# L005a  March 18.  Dear Madam, This letter will be del...  Mr. Villars
# ...                                                  ...          ...
# L081c  e's name.  The views which I am now going to a...            ?
# L081d  Sir, The letter you have been pleased to addre...            ?
# L082a  !" I  could make no reply; indeed I hardly spo...            ?
# L083a  urity of thy mind may form the brightest splen...  Mr. Villars
# L084a  All is over, my dearest Sir, and the fate of y...      Evelina
#
#                     recip_tok  num_words  \
# id
# L001a             Mr. Villars        566
# L002a             Lady Howard       1470
# L003a             Mr. Villars        431
# L004a             Lady Howard        891
# L005a             Lady Howard        124
# ...                       ...        ...
# L081c            Miss Anville        478
# L081d  Sir Clement Willoughby         92
# L082a                       ?       5640
# L083a                 Evelina        373
# L084a             Mr. Villars         65
#
#                                    date_ner            date_time  \
# id
# L001a
# L002a
# L003a  some months after the last | March 8                 None
# L004a                   2022-03-12 00:00:00  2022-03-12 00:00:00
# L005a                   2022-03-18 00:00:00  2022-03-18 00:00:00
# ...                                     ...                  ...
# L081c
# L081d
# L082a                   2022-10-13 00:00:00  2022-10-13 00:00:00
# L083a
# L084a                          This morning                 None
#
#                       place_ner id_parent
# id
# L001a
# L002a  Berry Hill | Dorsetshire
# L003a
# L004a
# L005a
# ...                         ...       ...
# L081c                               L081b
# L081d                               L081b
# L082a                   Clifton
# L083a
# L084a
#
# [91 rows x 17 columns]

# %%
evelina_letters.meta.num_words.sum(), evelina.length
# Out:
# (153512, 155077)

# %%
# evelina_letters.meta.groupby('sender_tok').num_words.sum().sort_values(ascending=False)
# evelina_letters.meta.groupby('recip_tok').num_words.sum().sort_values(ascending=False)

# %% [markdown]
# ## Haywood

# %%
betsy = C.textd['_chadwyck/Eighteenth-Century_Fiction/haywood.02']
betsy_letters = betsy.sections
betsy_letters.meta
# Out:
# [10:51:14] lltk.corpus.corpus.metadata():251: Generating metadata dataframe
# [10:51:14] lltk.corpus.corpus.init():234: Initializing from metadata: [SectionCorpusLetterChadwyck](_chadwyck/EighteenthCentury_Fiction/haywood02/sections)
# Iterating over texts: 100%|██████████| 78/78 [00:00<00:00, 235.03it/s]
# [10:51:14] lltk.corpus.corpus.metadata():264: Returning dataframe of (78, 15) dimensions
#           id_orig vol_i letter_i letter_ii num_enclosed depth_enclosed  \
# id
# L001a  Z300029804     1        1         0            0              0
# L002b  Z300029805     1        2         1            0              0
# L002c  Z300029805     1        2         2            0              0
# L003a  Z300029809     1        3         0            0              0
# L004a  Z300029810     1        4         0            0              0
# ...           ...   ...      ...       ...          ...            ...
# L048d  Z300029901     4       48         3            0              0
# L048e  Z300029901     4       48         4            0              0
# L048f  Z300029901     4       48         5            0              0
# L049b  Z300029902     4       49         1            0              0
# L049c  Z300029902     4       49         2            0              0
#
#           txt_head                                          txt_front  \
# id
# L001a   CHAP. III.  Affords matter of condolance, or railery, acco...
# L002b     CHAP IV.  Verifies the old proverb, that one affliction ...
# L002c
# L003a  CHAP. VIII.  Relates how, by a concurrence of odd circumsta...
# L004a    CHAP. IX.  Contains such things as might be reasonably ex...
# ...            ...                                                ...
# L048d                                                 To mrs. Munden,
# L048e                                      To Charles Trueworth, Esq;
# L048f                                      To Charles Trueworth, Esq;
# L049b  CHAP. XXIV.  Is the last, and if the author's word may be t...
# L049c                                      To Charles Trueworth, Esq;
#
#                                                txt_start  \
# id
# L001a  "Dear Miss, I must certainly be either the mos...
# L002b  "Most adored of your sex, I doubt not but you ...
# L002c  "Sir, Tho' it is my fixed determination to enc...
# L003a  Most dear and honoured madam, "My brother Fran...
# L004a  "My dear sister, I have endangered my life, an...
# ...                                                  ...
# L048d  ''Madam, I am now more unhappy than ever;   --...
# L048e  ''Sir, The generous concern you express for my...
# L048f  ''Sir, I should be unjust to myself, as well a...
# L049b  ''Madam, The year of my probation is expired; ...
# L049c  ''Sir, I Know there is a great share of impati...
#
#                                                  txt_end sender_tok  \
# id
# L001a  er the most ungrateful, or most consumedly dul...          ?
# L002b  even tho' it be to take a last farewell. I hav...          ?
# L002c  "Sir, Tho' it is my fixed determination to enc...          ?
# L003a  Most dear and honoured madam, "My brother Fran...          ?
# L004a  "My dear sister, I have endangered my life, an...          ?
# ...                                                  ...        ...
# L048d  ''Madam, I am now more unhappy than ever;   --...          ?
# L048e  ''Sir, The generous concern you express for my...          ?
# L048f  ''Sir, I should be unjust to myself, as well a...          ?
# L049b  ontrary to your nature, forbid me to approach ...          ?
# L049c  of impatience in the composition of your sex, ...          ?
#
#                recip_tok num_words date_ner date_time
# id
# L001a                  ?       199
# L002b                  ?       533
# L002c                  ?        92
# L003a                  ?       137
# L004a                  ?       118
# ...                  ...       ...      ...       ...
# L048d                  ?       101
# L048e  Charles Trueworth        56
# L048f  Charles Trueworth        84
# L049b        Mrs. Munden       228
# L049c  Charles Trueworth       197
#
# [78 rows x 15 columns]

# %%
betsy_letters.meta.groupby('sender_tok').num_words.sum().sort_values(ascending=False)
# betsy_letters.meta.groupby('recip_tok').num_words.sum().sort_values(ascending=False)
# Out:
# Iterating over texts:  33%|███▎      | 64/196 [00:33<01:09,  1.89it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/lltk/corpus/epistolary/test_epistolary.ipynb Cell 16' in <module>
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/lltk/corpus/epistolary/test_epistolary.ipynb#ch0000063?line=0'>1</a> betsy_letters.meta.groupby('sender_tok').num_words.sum().sort_values(ascending=False)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:2189, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2184'>2185</a> # If we are grouping on categoricals we want unobserved categories to
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2185'>2186</a> # return zero, rather than the default of NaN which the reindexing in
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2186'>2187</a> # _agg_general() returns. GH #31422
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2187'>2188</a> with com.temp_setattr(self, "observed", True):
# -> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2188'>2189</a>     result = self._agg_general(
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2189'>2190</a>         numeric_only=numeric_only,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2190'>2191</a>         min_count=min_count,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2191'>2192</a>         alias="add",
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2192'>2193</a>         npfunc=np.sum,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2193'>2194</a>     )
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=2195'>2196</a> return self._reindex_output(result, fill_value=0)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1506, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1493'>1494</a> @final
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1494'>1495</a> def _agg_general(
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1495'>1496</a>     self,
#    (...)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1500'>1501</a>     npfunc: Callable,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1501'>1502</a> ):
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1503'>1504</a>     with self._group_selection_context():
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1504'>1505</a>         # try a cython aggregation if we can
# -> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1505'>1506</a>         result = self._cython_agg_general(
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1506'>1507</a>             how=alias,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1507'>1508</a>             alt=npfunc,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1508'>1509</a>             numeric_only=numeric_only,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1509'>1510</a>             min_count=min_count,
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1510'>1511</a>         )
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1511'>1512</a>         return result.__finalize__(self.obj, method="groupby")
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1592, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1587'>1588</a>     return result
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1589'>1590</a> # TypeError -> we may have an exception in trying to aggregate
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1590'>1591</a> #  continue and exclude the block
# -> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1591'>1592</a> new_mgr = data.grouped_reduce(array_func, ignore_failures=True)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1593'>1594</a> if not is_ser and len(new_mgr) < len(data):
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1594'>1595</a>     warn_dropping_nuisance_columns_deprecated(type(self), how)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=192'>193</a> """
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=193'>194</a> ignore_failures : bool, default False
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=194'>195</a>     Not used; for compatibility with ArrayManager/BlockManager.
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=195'>196</a> """
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=197'>198</a> arr = self.array
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=198'>199</a> res = func(arr)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=199'>200</a> index = default_index(len(res))
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/internals/base.py?line=201'>202</a> mgr = type(self).from_array(res, index)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1578, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1575'>1576</a> def array_func(values: ArrayLike) -> ArrayLike:
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1576'>1577</a>     try:
# -> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1577'>1578</a>         result = self.grouper._cython_operation(
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1578'>1579</a>             "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1579'>1580</a>         )
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1580'>1581</a>     except NotImplementedError:
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1581'>1582</a>         # generally if we have numeric_only=False
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1582'>1583</a>         # and non-applicable functions
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1583'>1584</a>         # try to python agg
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1584'>1585</a>         # TODO: shouldn't min_count matter?
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py?line=1585'>1586</a>         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=936'>937</a> ids, _, _ = self.group_info
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=937'>938</a> ngroups = self.ngroups
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=938'>939</a> return cy_op.cython_operation(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=939'>940</a>     values=values,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=940'>941</a>     axis=axis,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=941'>942</a>     min_count=min_count,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=942'>943</a>     comp_ids=ids,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=943'>944</a>     ngroups=ngroups,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=944'>945</a>     **kwargs,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=945'>946</a> )
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:626, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=615'>616</a> if not isinstance(values, np.ndarray):
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=616'>617</a>     # i.e. ExtensionArray
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=617'>618</a>     return self._ea_wrap_cython_operation(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=618'>619</a>         values,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=619'>620</a>         min_count=min_count,
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=622'>623</a>         **kwargs,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=623'>624</a>     )
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=625'>626</a> return self._cython_op_ndim_compat(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=626'>627</a>     values,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=627'>628</a>     min_count=min_count,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=628'>629</a>     ngroups=ngroups,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=629'>630</a>     comp_ids=comp_ids,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=630'>631</a>     mask=None,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=631'>632</a>     **kwargs,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=632'>633</a> )
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:451, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=448'>449</a> if result_mask is not None:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=449'>450</a>     result_mask = result_mask[None, :]
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=450'>451</a> res = self._call_cython_op(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=451'>452</a>     values2d,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=452'>453</a>     min_count=min_count,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=453'>454</a>     ngroups=ngroups,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=454'>455</a>     comp_ids=comp_ids,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=455'>456</a>     mask=mask,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=456'>457</a>     result_mask=result_mask,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=457'>458</a>     **kwargs,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=458'>459</a> )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=459'>460</a> if res.shape[0] == 1:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=460'>461</a>     return res[0]
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:535, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=522'>523</a>     func(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=523'>524</a>         result,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=524'>525</a>         counts,
#    (...)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=530'>531</a>         is_datetimelike=is_datetimelike,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=531'>532</a>     )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=532'>533</a> elif self.how in ["add"]:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=533'>534</a>     # We support datetimelike
# --> <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=534'>535</a>     func(
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=535'>536</a>         result,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=536'>537</a>         counts,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=537'>538</a>         values,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=538'>539</a>         comp_ids,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=539'>540</a>         min_count,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=540'>541</a>         datetimelike=is_datetimelike,
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=541'>542</a>     )
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=542'>543</a> else:
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/pandas/core/groupby/ops.py?line=543'>544</a>     func(result, counts, values, comp_ids, min_count)
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/groupby.pyx:540, in pandas._libs.groupby.group_add()
#
# TypeError: can only concatenate str (not "int") to str

# %%
betsy_letters.meta.num_words.sum(), betsy.length
# Out:
# (20749, 226950)
