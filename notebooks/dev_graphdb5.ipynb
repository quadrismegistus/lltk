# %%
import sys; sys.path.insert(0,'../../yapmap')
import sys; sys.path.insert(0,'..')
from lltk import *
# log.verbose=2

# %%
t=Text(title="Dawn of Everything", author="Graeber")

# %%
# %%timeit
with log: t.cache_db()
# Out:
# [17:42:27] lltk.tools.tools.is_cacheworthy( cache unchanged )

# %%
# %%timeit
t.cache_json()
# Out:
# 116 µs ± 847 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t.init_cache_db()
# Out:
# {'id': 'author=Graeber/title=Dawn_of_Everything',
#  'author': 'Graeber',
#  'title': 'Dawn of Everything'}

# %%
gdb.get_node(['X'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/notebooks/dev_graphdb5.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/notebooks/dev_graphdb5.ipynb#ch0000004?line=0'>1</a> gdb.get_node(['X'])
#
# NameError: name 'gdb' is not defined

# %%
gdb.db.atomic(gdb.path, gdb.db.connec)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/ryan/github/lltk/notebooks/dev_graphdb4.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/notebooks/dev_graphdb4.ipynb#ch0000041?line=0'>1</a> gdb.db.visualize(gdb.path, 'test.dot', ['X'])
#
# File ~/miniforge3/lib/python3.9/site-packages/simple_graph_sqlite/database.py:248, in visualize(db_file, dot_file, path, connections, format, exclude_node_keys, hide_node_key, node_kv, exclude_edge_keys, hide_edge_key, edge_kv)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/simple_graph_sqlite/database.py?line=245'>246</a> ids.append(i)
#     <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/simple_graph_sqlite/database.py?line=246'>247</a> for edge in atomic(db_file, connections(i)):
# ...

# %%
dbx=gdb._db
# Out:
# Signature: dbx.get_connections(identifier)
# Docstring: <no docstring>
# Source:
# def get_connections(identifier):
#     def _get_connections(cursor):
#         return cursor.execute(read_sql('search-edges.sql'), (identifier, identifier,)).fetchall()
#     return _get_connections
# File:      ~/miniforge3/lib/python3.9/site-packages/simple_graph_sqlite/database.py
# Type:      function

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/notebooks/dev_graphdb4.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/notebooks/dev_graphdb4.ipynb#ch0000038?line=0'>1</a> list(gdb.db.get_connections('X'))
#
# TypeError: 'function' object is not iterable

# %%
gdb.get_node('X')
# Out:
# {'name': 'XXX', 'id': 'X'}

# %%
os.path.exists(gdb.path)
# Out:
# True

# %%
gdb.add_node('X',name='XXX')

# %%
gdb.add_node('Y',name='XXX')

# %%
gdb.add_edge('X','Y',rel='whoknows')

# %%
# !cat {gdb.path}
# Out:
# CC!]indextarget_idxedgeCREATE INDEX target_idx ON edges(target)C!]indexsource_idxedgesCREATE INDEX source_idx ON edges(source)��etableedgesedgesCREATE TABLE edges (
#     source     TEXT,
#     target     TEXT,
#     properties TEXT,
#     UNIQUE(source, target, properties) ON CONFLICT REPLACE,
#     FOREIGN KEY(source) REFERENCES nodes(id),
#     FOREIGN KEY(target) REFERENCES nodes(id)
# ))=indexsqlite_autoindex_edges_1edges7Mindexid_idxnodesCREATE INDEX id_idx ON nodes(id)��tablenodesnodesCREATE TABLE nodes (
#     body TEXT,
#     id   TEXT GENERATED ALWAYS AS (json_extract(body, '$.id')) VIRTUAL NOT NULL UNIQUE
# ���;{"name":"XXX","id":"Y"};{"name":"XXX","id":"X"}
# ���Y	X
# ��1XY{"rel":"whoknows"}
# ��1	XY{"rel":"whoknows"}
# ��	X
# ��	Y
