# %% [markdown]
# # Document-term matrices

# %%
import lltk

# %%
C=lltk.load('txtlab')

# %%
# C.install()
C.compile()
# Out:
# [TxtLab] Extracting texts from txtlab_raw.zip: 100%|██████████| 460/460 [00:01<00:00, 261.04it/s]
# [TxtLab] Saved: README.md
# [TxtLab] Saved: metadata.csv

# %%
C.preprocess(force=True)
# Out:
# [TxtLab] Saving word freqs as jsons [x4]: 100%|██████████| 410/410 [00:05<00:00, 71.45it/s]
# [TxtLab] Counting overall most frequent words (MFW) [x4]: 100%|██████████| 410/410 [00:03<00:00, 109.87it/s]
# [TxtLab] Assembling document-term matrix (DTM) [x4]: 100%|██████████| 410/410 [00:01<00:00, 228.86it/s]

# %%
dtm=C.dtm(meta=['language'])
dtm
# Out:
#                                                              the  and      de  \
# id                                                 language
# DE_1774_Goethe,Johann_DieLeidendesjungenWerther... German    0.0  0.0     2.0
# DE_1774_Wieland,ChristophMartin_GeschichtederAb... German    0.0  0.0     6.0
# DE_1776_Nicolai,Friedrich_SebaldusNothanker_Novel  German    3.0  7.0    34.0
# DE_1779_Campe,Joachim_Robinson_Novel               German    0.0  0.0     0.0
# DE_1779_Jacobi,Friedrich_Woldemar_Novel            German    0.0  0.0    20.0
# ...                                                          ...  ...     ...
# FR_1926_Giraudoux,Jean_Bella_Novel                 French    0.0  0.0  2387.0
# FR_1926_Ramuz,CharlesFerdinand_GrandePeurDansla... French    0.0  0.0  1710.0
# FR_1927_Bernanos,Georges_Limposture_Novel          French    0.0  0.0  3441.0
# FR_1927_Duhamel,Georges_JournaldeSalavin_Novel     French    0.0  0.0  1493.0
# ...

# %%
dtmx = dtm#.xs('English',level='language')
dtmx
# Out:
#                                                              the  and      de  \
# id                                                 language
# DE_1774_Goethe,Johann_DieLeidendesjungenWerther... German    0.0  0.0     2.0
# DE_1774_Wieland,ChristophMartin_GeschichtederAb... German    0.0  0.0     6.0
# DE_1776_Nicolai,Friedrich_SebaldusNothanker_Novel  German    3.0  7.0    34.0
# DE_1779_Campe,Joachim_Robinson_Novel               German    0.0  0.0     0.0
# DE_1779_Jacobi,Friedrich_Woldemar_Novel            German    0.0  0.0    20.0
# ...                                                          ...  ...     ...
# FR_1926_Giraudoux,Jean_Bella_Novel                 French    0.0  0.0  2387.0
# FR_1926_Ramuz,CharlesFerdinand_GrandePeurDansla... French    0.0  0.0  1710.0
# FR_1927_Bernanos,Georges_Limposture_Novel          French    0.0  0.0  3441.0
# FR_1927_Duhamel,Georges_JournaldeSalavin_Novel     French    0.0  0.0  1493.0
# ...

# %%
# dtmx_tfidf=lltk.dtm2tfidf(dtmx)
dtmx_tfidf.droplevel('language')
# Out:
#                                                          the       and  \
# id
# DE_1774_Goethe,Johann_DieLeidendesjungenWerther...  0.000000  0.000000
# DE_1774_Wieland,ChristophMartin_GeschichtederAb...  0.000000  0.000000
# DE_1776_Nicolai,Friedrich_SebaldusNothanker_Novel   0.000001  0.000004
# DE_1779_Campe,Joachim_Robinson_Novel                0.000000  0.000000
# DE_1779_Jacobi,Friedrich_Woldemar_Novel             0.000000  0.000000
# ...                                                      ...       ...
# FR_1926_Giraudoux,Jean_Bella_Novel                  0.000000  0.000000
# FR_1926_Ramuz,CharlesFerdinand_GrandePeurDansla...  0.000000  0.000000
# FR_1927_Bernanos,Georges_Limposture_Novel           0.000000  0.000000
# FR_1927_Duhamel,Georges_JournaldeSalavin_Novel      0.000000  0.000000
# FR_1929_Dabit,Eugene_LhotelduNord_Novel             0.000000  0.000000
#
#                                                               de        of  \
# id
# ...

# %%
dtmx_tfidf.loc['EN_1778_Burney,Fanny_Evelina_Novel'].dropna().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-02a967936e9a> in <module>
# ----> 1 dtmx_tfidf.loc['EN_1778_Burney,Fanny_Evelina_Novel'].dropna().sort_values(ascending=False).head(10)
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
