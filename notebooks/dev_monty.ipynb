# %%
import sys; sys.path.insert(0,'..')
from lltk import *

# %%
mdb=LLTK.mdb

# %%
# C=Corpus('chicago')
# ld=[t.meta for t in C]

# %%
from montydb import set_storage, MontyClient
fn="/Users/ryan/Desktop/testmonty.sqlite"
set_storage(fn, storage="sqlite")#cache_modified=0)  # optional step
# client = MontyClient(fn)  # use current working dir if no path given
client = MontyClient(
    fn,
    busy_timeout=5000,
    synchronous="FULL",
    automatic_index=True
)
client
# Out:
# MontyClient(repository='/Users/ryan/Desktop/testmonty.sqlite', document_class=builtins.dict, storage_engine=MontyStorage(engine: 'SQLiteStorage'))

# %%
db = client.db.metadata
db.drop()
db = client.db.metadata

# %%
# db.insert_many(ld)

# %%
# %%timeit
res=list(db.find(dict(_corpus='chicago')))
res[0], len(res)
# Out:
# ({'id': 1,
#   '_addr': '_chicago/00000001',
#   '_corpus': 'chicago',
#   '_id': 1,
#   '_type': 'Text',
#   'auth_first': 'Henry',
#   'auth_id': 'A_00017',
#   'auth_last': 'Adams',
#   'author': 'Adams, Henry',
#   'book_id': 1,
#   'clean': 'c',
#   'date_b': 1838,
#   'date_d': 1918,
#   'education': 'Harvard',
#   'filename': '00000001.txt',
#   'gender': 'M',
#   'genre': 'Fiction',
#   'geography': 'Boston, MA; Washington, DC',
#   'libraries': 152,
#   'nationality': 'American',
#   'publ_city': 'New York',
#   'publ_date': 1880,
#   'publisher': 'Henry Holt & Co.',
#   'race_ethnicity': 'Caucasian',
#   'secondary_occupation': 'Historian',
#   'source': 'g',
#   'title': 'Democracy',
#   'year': 1880},
#  9089)

# %%
for d in get_tqdm(ld):
    db.update_one({'_addr':d['_addr']}, {"$set":just_meta_no_id(d)}, upsert=True)
# Out:
#   0%|          | 0/9089 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/lib/python3.9/site-packages/montydb/engine/queries.py:157, in LogicBox.__call__(self, fieldwalker)
#     156 try:
# --> 157     return self._logic[self.theme](fieldwalker)
#     158 except KeyError:
#
# KeyError: '_addr'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 for d in get_tqdm(ld):
# ----> 2     db.update_one({'_addr':d['_addr']}, {"$set":just_meta_no_id(d)}, upsert=True)
#
# File ~/miniforge3/lib/python3.9/site-packages/montydb/collection.py:311, in MontyCollection.update_one(self, filter, update, upsert, bypass_document_validation, array_filters, *args, **kwargs)
#     309 self._no_id_update(updator, filter)
# ...

# %%
db??
# Out:
# Type:            MontyCollection
# String form:     MontyCollection(MontyDatabase(MontyClient(repository='/Users/ryan/Desktop/testmonty.db', document_class=builtins.dict, storage_engine=MontyStorage(engine: 'FlatFileStorage')), 'db'), 'metadata')
# File:            ~/miniforge3/lib/python3.9/site-packages/montydb/collection.py
# Source:
# class MontyCollection(BaseObject):
#     def __init__(
#         self,
#         database,
#         name,
#         create=False,
#         codec_options=None,
#         write_concern=None,
#         **kwargs
#     ):
#         """ """
#         super(MontyCollection, self).__init__(
#             codec_options or database.codec_options,
#             write_concern or database.write_concern,
#         )
#
#         self._storage = database.client._storage
#
#         self._database = database
#         self._name = name
#         self._components = (database, self)
#
#     def __repr__(self):
# ...
