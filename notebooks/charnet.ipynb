# %% [markdown]
# # CharNet Model

# %%
from lltk.model.charnet import *

# %%
ner_txt2names("""
Mr. Bennet was among the earliest of those who waited on Mr. Bingley. He had always intended to visit him, though to the last always assuring his wife that he should not go; and till the evening after the visit was paid she had no knowledge of it. It was then disclosed in the following manner. Observing his second daughter employed in trimming a hat, he suddenly addressed her with:

“I hope Mr. Bingley will like it, Lizzy.”
""")
# Out:
# 2021-02-07 18:24:44 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | ner       | ontonotes |
# ...
#
# 2021-02-07 18:24:44 INFO: Use device: cpu
# 2021-02-07 18:24:44 INFO: Loading: tokenize
# 2021-02-07 18:24:44 INFO: Loading: ner
# 2021-02-07 18:24:44 INFO: Done loading processors!
# Parsing paragraphs: 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
# Counter({'Bennet': 1, 'Bingley': 2, 'second': 1, 'Lizzy': 1})

# %%
# big text

# %%
import lltk
C=lltk.load('CanonFiction')
t=[t for t in C.texts() if t.title.startswith('Pride and Prej')][0]
t

# %%
t.title
# Out:
# 'Pride and Prejudice: A Novel.'

# %%
# t.txt

# %%
len(t.words)
# Out:
# 126397

# %%
# ppnames = ner_txt2names(t.txt)
# ppnames.most_common()

# %%
# t2=[t for t in C.texts() if t.title=='Don Quixote'][0]
# dqnames=ner_txt2names(t2.txt)
# dqnames.most_common()

# %%
t3=[t for t in C.texts() if t.author=='Heliodorus'][0]
t3

# %%
ner_txt2names(t3.txt)
# Out:
# 2021-02-07 18:27:55 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | ner       | ontonotes |
# ...
#
# 2021-02-07 18:27:55 INFO: Use device: cpu
# 2021-02-07 18:27:55 INFO: Loading: tokenize
# 2021-02-07 18:27:55 INFO: Loading: ner
# 2021-02-07 18:27:55 INFO: Done loading processors!
# Parsing paragraphs: 100%|██████████| 338/338 [10:10<00:00,  1.81s/it]
# Counter({'first': 115,
#          'Nile': 42,
#          'Heracleot': 3,
#          'third': 8,
#          'some half': 1,
#          '8': 1,
#          'one': 115,
#          'Egypt': 32,
#          '10': 1,
#          'Artemis': 2,
#          'Egyptians': 17,
#          '11': 1,
#          'two': 52,
#          'ten': 7,
#          'three': 12,
#          '12': 1,
#          '13': 1,
#          'about two': 1,
#          'The Pasture Land': 1,
#          '14': 1,
#          'Lake': 1,
#          'the next day': 7,
#          'Grecian': 9,
# ...
