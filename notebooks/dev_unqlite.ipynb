# %%
import sys; sys.path.insert(0,'..')
from lltk import *

# %%
mdb=LLTK.mdb

# %%
mdb.db.fetch(3)
# Out:
# {'author': 'Cumberland, Richard, 1732-1811',
#  'title': 'THE FASHIONABLE LOVER; A COMEDY: As it is acted at the THEATRE-ROYAL IN DRURY-LANE.',
#  'year': '1772',
#  'fn': 'K000180.000.txt',
#  'id_tedjdh': 'CumbRFL',
#  'genre': 'Drama',
#  'num_words': '21157',
#  'num_words2': '20169.0',
#  'ocr_accuracy': '0.949094862221',
#  '_type': 'Text',
#  '_corpus': 'tedjdh',
#  'id': '_tedjdh/K000180.000',
#  '__id': 3}

# %%
mdb.where(_corpus='chadwyck')
# Out:
# [{'author': 'Paltock, Robert, 1697-1767',
#   'title': 'Peter Wilkins (1751)',
#   'year': '1751',
#   'idref': 'Z200043982',
#   'pub': 'Printed for J. Robinson, ... and R. Dodsley, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/paltock.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/paltock.01',
#   '__id': 554892},
#  {'author': 'Brooke, Frances, 1724?-1789',
#   'title': 'Lady Julia Mandeville (1763)',
#   'year': '1763',
#   'idref': 'Z200000703',
#   'pub': 'Printed for R. and J. Dodsley [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/brookefm.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/brookefm.02',
#   '__id': 554893},
#  {'author': 'Mackenzie, Henry, 1745-1831',
#   'title': 'Julia de Roubign&eacute; (1777)',
#   'year': '1777',
#   'idref': 'Z200030400',
#   'pub': 'Printed for W. Strahan, and T. Cadell',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/mackenzi.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/mackenzi.01',
#   '__id': 554894},
#  {'author': 'Cleland, John, 1709-1789',
#   'title': 'Memoirs of a Woman of Pleasure (1749)',
#   'year': '1749',
#   'idref': 'Z200000927',
#   'pub': 'Printed for G. Fenton [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/cleland.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/cleland.01',
#   '__id': 554895},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Fortunate Foundlings (1744)',
#   'year': '1744',
#   'idref': 'Z200029933',
#   'pub': 'Printed and published by T. Gardner [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.07.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.07',
#   '__id': 554896},
#  {'author': 'Johnstone, Charles, 1719?-1800?',
#   'title': 'Chrysal (1760)',
#   'year': '1760',
#   'idref': 'Z200030192',
#   'pub': 'Printed for T. Beckett, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/johnston.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/johnston.01',
#   '__id': 554897},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Moll Flanders (1722)',
#   'year': '1722',
#   'idref': 'Z200001100',
#   'pub': 'Printed for John Brotherton, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.06',
#   '__id': 554898},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Sir Charles Grandison (1754)',
#   'year': '1754',
#   'idref': 'Z200045835',
#   'pub': 'Printed for S. Richardson; And Sold by C. Hitch and L. Hawes ... ; By J. and J. Rivington ... ; By Andrew Millar [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.06',
#   '__id': 554899},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'Roderick Random (1748)',
#   'year': '1748',
#   'idref': 'Z200046674',
#   'pub': 'Printed for J. Osborn',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.05',
#   '__id': 554900},
#  {'author': 'Davys, Mary, 1674-1731',
#   'title': 'Familiar Letters betwixt a Gentleman and a Lady',
#   'year': '1725',
#   'idref': 'Z200000995',
#   'pub': 'Printed by H. Woodfall, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/davys.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/davys.03',
#   '__id': 554901},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Journal of the Plague Year (1722)',
#   'year': '1722',
#   'idref': 'Z200001074',
#   'pub': 'Printed for E. Nutt ... J. Roberts ... A. Dodd [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.04',
#   '__id': 554902},
#  {'author': 'Sheridan, Frances Chamberlaine, 1724-1766',
#   'title': 'Conclusion of the Memoirs of Miss Sidney Bidulph (1770)',
#   'year': '1770',
#   'idref': 'Z200046250',
#   'pub': 'Printed for J. Dodsley, in Pall&hyphen;mall',
#   'type': 'BOOK',
#   'name': 'Vol. 4',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sheridan.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sheridan.01',
#   '__id': 554903},
#  {'author': 'Walpole, Horace, 1717-1797',
#   'title': 'The Castle of Otranto (1764)',
#   'year': '1764',
#   'idref': 'Z200047336',
#   'pub': 'Printed for Tho. Lownds [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/walpole.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/walpole.01',
#   '__id': 554904},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Memoirs of a Cavalier (1720)',
#   'year': '1720',
#   'idref': 'Z200001086',
#   'pub': 'Printed for A. Bell ... J. Osborn ... W. Taylor [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.05',
#   '__id': 554905},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Robinson Crusoe (1719)',
#   'year': '1719',
#   'idref': 'Z200001112',
#   'pub': 'Printed for W. Taylor [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.07.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.07',
#   '__id': 554906},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Idalia (1725): a machine&hyphen; readable transcript',
#   'year': '1725',
#   'idref': 'Z200029965',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.08.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.08',
#   '__id': 554907},
#  {'author': 'Lennox, Charlotte, ca. 1729-1804',
#   'title': 'The Female Quixote (1752)',
#   'year': '1752',
#   'idref': 'Z200030275',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/lennox.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/lennox.01',
#   '__id': 554908},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Lasselia (1725)',
#   'year': '1725',
#   'idref': 'Z200030083',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.11.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.11',
#   '__id': 554909},
#  {'author': 'Fielding, Sarah, 1710-1768',
#   'title': 'Countess of Dellwyn (1759)',
#   'year': '1759',
#   'idref': 'Z200029249',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldins.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldins.01',
#   '__id': 554910},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'Peregrine Pickle (1751)',
#   'year': '1751',
#   'idref': 'Z200046541',
#   'pub': 'Printed for the Author [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.04',
#   '__id': 554911},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Love in Excess (1725)',
#   'year': '1725',
#   'idref': 'Z200030091',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.12.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.12',
#   '__id': 554912},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Roxana (1724)',
#   'year': '1724',
#   'idref': 'Z200001123',
#   'pub': 'Printed for T. Warner ... W. Meadows ... W. Pepper [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.08.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.08',
#   '__id': 554913},
#  {'author': 'Sheridan, Frances Chamberlaine, 1724-1766',
#   'title': 'The History of Nourjahad (1767)',
#   'year': '1767',
#   'idref': 'Z200046333',
#   'pub': 'Printed for J. Dodsley in Pall&hyphen;Mall',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sheridan.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sheridan.02',
#   '__id': 554914},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'Shamela (1741)',
#   'year': '1741',
#   'idref': 'Z200028978',
#   'pub': 'Printed for A. Dodd, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.05',
#   '__id': 554915},
#  {'author': 'Burney, Fanny, 1752-1840',
#   'title': 'Evelina (1778)',
#   'year': '1778',
#   'idref': 'Z200000830',
#   'pub': 'Printed for T. Lowndes, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/burney.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/burney.01',
#   '__id': 554916},
#  {'author': 'Swift, Jonathan, 1667-1745',
#   'title': "Gulliver's Travels (Motte ed.) (1726)",
#   'year': '1726',
#   'idref': 'Z200047277',
#   'pub': 'Printed for Benj. Motte, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/swift.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/swift.02',
#   '__id': 554917},
#  {'author': 'Manley, Mrs. (Mary de la Rivi&egrave;re), 1663-1724',
#   'title': 'The Adventures of Rivella (1714)',
#   'year': '1714',
#   'idref': 'Z200030553',
#   'pub': 'Printed for W. Strahan; and T. Cadell, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/manley.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/manley.01',
#   '__id': 554918},
#  {'author': 'Brooke, Frances, 1724?-1789',
#   'title': 'Emily Montague (1769) ',
#   'year': '1769',
#   'idref': 'Z200000460',
#   'pub': 'Printed for J. Dodsley, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/brookefm.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/brookefm.01',
#   '__id': 554919},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Fatal Secret (1725): a machine&hyphen; readable transcript',
#   'year': '1725',
#   'idref': 'Z200029919',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.05',
#   '__id': 554920},
#  {'author': 'Barker, Jane',
#   'title': 'Bosvil and Galesia (1719)',
#   'year': '1719',
#   'idref': 'Z200000393',
#   'pub': 'Printed for A. Bettesworth, ... and E. Curll [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/barker.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/barker.01',
#   '__id': 554921},
#  {'author': 'Manley, Mrs. (Mary de la Rivi&egrave;re), 1663-1724',
#   'title': 'Queen Zarah (1705)',
#   'year': '1705',
#   'idref': 'Z200030604',
#   'pub': 'Printed for John Barber ... and John Morphew, [etc.]',
#   'type': 'BOOK',
#   'name': 'Part 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/manley.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/manley.05',
#   '__id': 554922},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Pamela (1741)',
#   'year': '1741',
#   'idref': 'Z200045357',
#   'pub': "Printed for C. Rivington, in St. Paul's Church&hyphen;Yard; and J. Osborn [etc.]",
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.04',
#   '__id': 554923},
#  {'author': 'Sterne, Laurence, 1713-1768',
#   'title': 'Tristram Shandy (1760)',
#   'year': '1760',
#   'idref': 'Z200046874',
#   'pub': 'Printed for R. and J. Dodsley in Pall&hyphen;Mall',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sterne.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sterne.03',
#   '__id': 554924},
#  {'author': 'Manley, Mrs. (Mary de la Rivi&egrave;re), 1663-1724',
#   'title': 'The Power of Love (1720)',
#   'year': '1720',
#   'idref': 'Z200030583',
#   'pub': 'Printed for John Barber ... and John Morphew, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/manley.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/manley.04',
#   '__id': 554925},
#  {'author': 'Reeve, Clara, 1729-1807',
#   'title': 'The Old English Baron (1780)',
#   'year': '1780',
#   'idref': 'Z200044046',
#   'pub': 'Printed for Charles Dilly',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/reeve.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/reeve.01',
#   '__id': 554926},
#  {'author': 'Davys, Mary, 1674-1731',
#   'title': "The Accomplish'd Rake",
#   'year': '1727',
#   'idref': 'Z200000979',
#   'pub': 'Sold by the Booksellers of London and Westminster',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/davys.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/davys.01',
#   '__id': 554927},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Rash Resolve (1725)',
#   'year': '1725',
#   'idref': 'Z200030118',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.14.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.14',
#   '__id': 554928},
#  {'author': 'Fielding, Sarah, 1710-1768 / Collier, Jane, 1709?-1754',
#   'title': 'The Cry (1754)',
#   'year': '1754',
#   'idref': 'Z200029391',
#   'pub': 'Printed for R. and J. Dodsley in Pall&hyphen;Mall',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinz.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinz.01',
#   '__id': 554929},
#  {'author': 'Brooke, Henry, 1703?-1783',
#   'title': 'The Fool of Quality (1765)',
#   'year': '1765',
#   'idref': 'Z200000786',
#   'pub': 'Printed for the Author by Dillon Chamberlaine, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/brookeh.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/brookeh.01',
#   '__id': 554930},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': "The Injur'd Husband (1725)",
#   'year': '1725',
#   'idref': 'Z200029976',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.09.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.09',
#   '__id': 554931},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Lucinda (1739)',
#   'year': '1739',
#   'idref': 'Z200000340',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.05',
#   '__id': 554932},
#  {'author': 'Amory, Thomas, 1691?-1788?',
#   'title': 'John Buncle (1756)',
#   'year': '1756',
#   'idref': 'Z200000003',
#   'pub': 'Printed for J. Noon, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/amory.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/amory.01',
#   '__id': 554933},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Fantomina (1725)',
#   'year': '1725',
#   'idref': 'Z200029913',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.04',
#   '__id': 554934},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'Amelia (1752)',
#   'year': '1752',
#   'idref': 'Z200028656',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.01',
#   '__id': 554935},
#  {'author': 'Goldsmith, Oliver, 1730?-1774',
#   'title': 'The Vicar of Wakefield (1766)',
#   'year': '1766',
#   'idref': 'Z200029460',
#   'pub': 'Printed by B. Collins, for F. Newbery ... London',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/goldsmit.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/goldsmit.01',
#   '__id': 554936},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Anti&hyphen;Pamela (1741)',
#   'year': '1741',
#   'idref': 'Z200029790',
#   'pub': 'Printed for J. Huggonson',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.01',
#   '__id': 554937},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Madam de Beaumount (1739)',
#   'year': '1739',
#   'idref': 'Z200000348',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.06',
#   '__id': 554938},
#  {'author': 'Fielding, Sarah, 1710-1768',
#   'title': 'David Simple (1744)',
#   'year': '1744',
#   'idref': 'Z200029308',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldins.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldins.02',
#   '__id': 554939},
#  {'author': 'Davys, Mary, 1674-1731',
#   'title': "The Lady's Tale (1725)",
#   'year': '1725',
#   'idref': 'Z200001022',
#   'pub': 'Printed by H. Woodfall, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/davys.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/davys.04',
#   '__id': 554940},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Familiar Letters (1750)',
#   'year': '1750',
#   'idref': 'Z200045177',
#   'pub': 'Printed for J. Osborn, ... J. and J. Rivington, ... and J. Leake, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.03',
#   '__id': 554941},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Masqueraders (1725)',
#   'year': '1725',
#   'idref': 'Z200030111',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.13.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.13',
#   '__id': 554942},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'The Farther Adventures of Robinson Crusoe (1719)',
#   'year': '1719',
#   'idref': 'Z200001062',
#   'pub': 'Printed for W. Taylor [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.03',
#   '__id': 554943},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'The History and Adventures of an Atom (1769)',
#   'year': '1769',
#   'idref': 'Z200046363',
#   'pub': 'Printed for Robinson and Roberts [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.01',
#   '__id': 554944},
#  {'author': 'Mackenzie, Henry, 1745-1831',
#   'title': 'The Man of the World (1773)',
#   'year': '1773',
#   'idref': 'Z200030487',
#   'pub': 'Printed for W. Strahan; and T. Cadell, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/mackenzi.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/mackenzi.03',
#   '__id': 554945},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Pamela (1742)',
#   'year': '1742',
#   'idref': 'Z200045598',
#   'pub': 'Printed for S. Richardson; And Sold by J. Osborn in Pater&hyphen;noster Row; and John Rivington [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.05',
#   '__id': 554946},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'A Journey from this World to the Next (1743)',
#   'year': '1743',
#   'idref': 'Z200028945',
#   'pub': 'Printed for the Author; [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.04',
#   '__id': 554947},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Count de Vinevil (1739)',
#   'year': '1739',
#   'idref': 'Z200000298',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.03',
#   '__id': 554948},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'Humphry Clinker (1771)',
#   'year': '1771',
#   'idref': 'Z200046450',
#   'pub': 'Printed for A. Leathley, J. Exshaw, H. Saunders, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.03',
#   '__id': 554949},
#  {'author': 'Coventry, Francis, 1725?-1759',
#   'title': 'Pompey the Little (1751)',
#   'year': '1751',
#   'idref': 'Z200000940',
#   'pub': 'Printed for M. Cooper, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/coventry.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/coventry.01',
#   '__id': 554950},
#  {'author': 'Manley, Mrs. (Mary de la Rivi&egrave;re), 1663-1724',
#   'title': 'Memoirs of Europe (1710)',
#   'year': '1710',
#   'idref': 'Z200030561',
#   'pub': 'Printed for John Morphew, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/manley.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/manley.02',
#   '__id': 554951},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'Sir Launcelot Greaves (1762)',
#   'year': '1762',
#   'idref': 'Z200046753',
#   'pub': 'Printed for J. Coote, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.06',
#   '__id': 554952},
#  {'author': 'Hawkesworth, John, 1715?-1773',
#   'title': 'Almoran and Hamet (1761)',
#   'year': '1761',
#   'idref': 'Z200029762',
#   'pub': 'Printed for H. Payne, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/hawkeswo.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/hawkeswo.01',
#   '__id': 554953},
#  {'author': 'Scott, Sarah, 1723-1795',
#   'title': 'Millenium Hall (1762)',
#   'year': '1762',
#   'idref': 'Z200046192',
#   'pub': 'Printed for J. Newbery, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/scott.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/scott.01',
#   '__id': 554954},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Captain Singleton (1720)',
#   'year': '1720',
#   'idref': 'Z200001040',
#   'pub': 'Printed for J. Brotherton, ... J. Graves ... A. Dodd, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.01',
#   '__id': 554955},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Count Albertus (1739)',
#   'year': '1739',
#   'idref': 'Z200000283',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.02',
#   '__id': 554956},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'Tom Jones (1749)',
#   'year': '1749',
#   'idref': 'Z200029000',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.06',
#   '__id': 554957},
#  {'author': 'Barker, Jane',
#   'title': 'The Lining of the Patch&hyphen;Work Screen (1726)',
#   'year': '1726',
#   'idref': 'Z200000423',
#   'pub': 'Printed for A. Bettesworth, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/barker.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/barker.03',
#   '__id': 554958},
#  {'author': 'Smollett, Tobias George, 1721-1771',
#   'title': 'Ferdinand Count Fathom (1753)',
#   'year': '1753',
#   'idref': 'Z200046375',
#   'pub': 'Printed for T. Johnson, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/smollett.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/smollett.02',
#   '__id': 554959},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'Jonathan Wild (1743)',
#   'year': '1743',
#   'idref': 'Z200028800',
#   'pub': 'Printed for the Author; [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.02',
#   '__id': 554960},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Clarissa (1st ed.) (1748)',
#   'year': '1748',
#   'idref': 'Z200044053',
#   'pub': 'Printed for S. Richardson: [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.01',
#   '__id': 554961},
#  {'author': 'Manley, Mrs. (Mary de la Rivi&egrave;re), 1663-1724',
#   'title': 'The New Atalantis (1709)',
#   'year': '1709',
#   'idref': 'Z200030574',
#   'pub': 'Printed for John Morphew ... and J. Woodward [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/manley.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/manley.03',
#   '__id': 554962},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Force of Nature (1725)',
#   'year': '1725',
#   'idref': 'Z200029926',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.06',
#   '__id': 554963},
#  {'author': 'Defoe, Daniel, 1661?-1731',
#   'title': 'Colonel Jack (1723)',
#   'year': '1723',
#   'idref': 'Z200001050',
#   'pub': 'Printed and Sold by J. Brotherton ... T. Payne ... W. Mears [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/defoe.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/defoe.02',
#   '__id': 554964},
#  {'author': 'Scott, Sarah, 1723-1795',
#   'title': 'Sir George Ellison (1766)',
#   'year': '1766',
#   'idref': 'Z200046203',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/scott.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/scott.02',
#   '__id': 554965},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Betsy Thoughtless (1751)',
#   'year': '1751',
#   'idref': 'Z200029799',
#   'pub': 'Printed by T. Gardner, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.02',
#   '__id': 554966},
#  {'author': 'Sterne, Laurence, 1713-1768',
#   'title': 'A Sentimental Journey (1768)',
#   'year': '1768',
#   'idref': 'Z200046796',
#   'pub': 'Printed for T. Becket and P. A. De Hondt',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sterne.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sterne.02',
#   '__id': 554967},
#  {'author': 'Swift, Jonathan, 1667-1745',
#   'title': "Gulliver's Travels (Faulkner ed.) (1735)",
#   'year': '1735',
#   'idref': 'Z200047224',
#   'pub': 'Printed by and for George Faulkner, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/swift.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/swift.01',
#   '__id': 554968},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The Surprise (1725)',
#   'year': '1725',
#   'idref': 'Z200030127',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.15.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.15',
#   '__id': 554969},
#  {'author': 'Fielding, Henry, 1707-1754',
#   'title': 'Joseph Andrews (1742)',
#   'year': '1742',
#   'idref': 'Z200028867',
#   'pub': 'Printed for A. Millar, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/fieldinh.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/fieldinh.03',
#   '__id': 554970},
#  {'author': 'Davys, Mary, 1674-1731',
#   'title': "The Reform'd Coquet (1725)",
#   'year': '1725',
#   'idref': 'Z200001029',
#   'pub': 'Printed by H. Woodfall, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/davys.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/davys.05',
#   '__id': 554971},
#  {'author': 'Barker, Jane',
#   'title': 'A Patch&hyphen;Work Screen (1723)',
#   'year': '1723',
#   'idref': 'Z200000448',
#   'pub': 'Printed for E. Curll, ... And T. Payne, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/barker.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/barker.04',
#   '__id': 554972},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'The Noble Slaves (1739)',
#   'year': '1739',
#   'idref': 'Z200000367',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.07.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.07',
#   '__id': 554973},
#  {'author': 'Barker, Jane',
#   'title': 'Exilius (1719)',
#   'year': '1719',
#   'idref': 'Z200000400',
#   'pub': 'Printed for A. Bettesworth,...and E. Curll [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/barker.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/barker.02',
#   '__id': 554974},
#  {'author': 'Lennox, Charlotte, ca. 1729-1804',
#   'title': 'Harriot Stuart (1751)',
#   'year': '1751',
#   'idref': 'Z200030385',
#   'pub': 'Printed for J. Payne, and J. Bouquet [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/lennox.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/lennox.02',
#   '__id': 554975},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Charlotta du Pont (1739)',
#   'year': '1739',
#   'idref': 'Z200000254',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.01',
#   '__id': 554976},
#  {'author': 'Sterne, Laurence, 1713-1768',
#   'title': 'A Political Romance (1759)',
#   'year': '1759',
#   'idref': 'Z200046787',
#   'pub': 'Roberts Brothers',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sterne.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sterne.01',
#   '__id': 554977},
#  {'author': 'Davys, Mary, 1674-1731',
#   'title': 'The Cousins (1725)',
#   'year': '1725',
#   'idref': 'Z200000988',
#   'pub': 'Printed by H. Woodfall, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/davys.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/davys.02',
#   '__id': 554978},
#  {'author': 'Graves, Richard, 1715-1804',
#   'title': 'The Spiritual Quixote (1773)',
#   'year': '1773',
#   'idref': 'Z200029500',
#   'pub': 'Printed for J. Dodsley, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/graves.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/graves.01',
#   '__id': 554979},
#  {'author': 'Johnson, Samuel, 1709-1784',
#   'title': 'Rasselas (1759)',
#   'year': '1759',
#   'idref': 'Z200030135',
#   'pub': 'Printed for R. and J. Dodsley ... and W. Johnston [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/johnson.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/johnson.01',
#   '__id': 554980},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'The British Recluse (1725)',
#   'year': '1725',
#   'idref': 'Z200029906',
#   'pub': 'Printed for Dan. Browne, Jun. ... and S. Chapman, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.03',
#   '__id': 554981},
#  {'author': 'Richardson, Samuel, 1689-1761',
#   'title': 'Clarissa (3rd ed.) (1751)',
#   'year': '1751',
#   'idref': 'Z200044604',
#   'pub': 'Printed for S. Richardson: [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/richards.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/richards.02',
#   '__id': 554982},
#  {'author': 'Mackenzie, Henry, 1745-1831',
#   'title': 'The Man of Feeling (1771)',
#   'year': '1771',
#   'idref': 'Z200030459',
#   'pub': 'Printed for T. Cadell, in the Strand',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/mackenzi.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/mackenzi.02',
#   '__id': 554983},
#  {'author': 'Haywood, Eliza Fowler, 1693?-1756',
#   'title': 'Jemmy and Jenny Jessamy (1753)',
#   'year': '1753',
#   'idref': 'Z200029987',
#   'pub': 'Printed for T. Gardner [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/haywood.10.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/haywood.10',
#   '__id': 554984},
#  {'author': 'Sheridan, Frances Chamberlaine, 1724-1766',
#   'title': 'Memoirs of Miss Sidney Bidulph (1761)',
#   'year': '1761',
#   'idref': 'Z200046338',
#   'pub': 'Printed for R. and J. Dodsley, [etc.]',
#   'type': 'BOOK',
#   'name': 'Vol. 1',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/sheridan.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/sheridan.03',
#   '__id': 554985},
#  {'author': 'Aubin, Penelope, 1679-1731',
#   'title': 'Lady Lucy (1739)',
#   'year': '1739',
#   'idref': 'Z200000324',
#   'pub': 'Printed for D. Midwinter, A. Bettesworth and C. Hitch, [etc.]',
#   'type': 'BOOK',
#   'name': 'Title Page',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Eighteenth-Century_Fiction',
#   'fn_raw': 'Eighteenth-Century_Fiction/aubin.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Eighteenth-Century_Fiction/aubin.04',
#   '__id': 554986},
#  {'author': 'Austen, Jane, 1775&ndash;1817',
#   'title': 'Pride and Prejudice: A Novel.',
#   'year': '1813',
#   'idref': 'Z200030914',
#   'pub': 'Printed for T. Egerton',
#   'type': 'BOOK',
#   'name': 'VOL. I.',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Nineteenth-Century_Fiction',
#   'fn_raw': 'Nineteenth-Century_Fiction/ncf0204.06.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Nineteenth-Century_Fiction/ncf0204.06',
#   '__id': 554987},
#  {'author': 'Hardy, Thomas, 1840&ndash;1928',
#   'title': 'Far from the Madding Crowd. By Thomas Hardy ... With Twelve Illustrations. In Two Volumes ... Second Edition',
#   'year': '1874',
#   'idref': 'Z200037705',
#   'pub': 'Smith, Elder &amp; Co.',
#   'type': 'BOOK',
#   'name': 'VOL. I.',
#   'nation': 'British',
#   'medium': 'Fiction',
#   'subcorpus': 'Nineteenth-Century_Fiction',
#   'fn_raw': 'Nineteenth-Century_Fiction/ncf23608.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
# ...
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/cooperja.50.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/cooperja.50',
#   '__id': 555863},
#  {'author': 'Paulding, James Kirke, 1778-1860',
#   'title': 'The Old Continental; or, The Price of Liberty, Volume 1 . . . (1846)',
#   'year': '1846',
#   'idref': 'Z100016276',
#   'pub': 'Paine and Burgess',
#   'type': 'BOOK',
#   'name': '<mainhead>The Old Continental; or, The Price of Liberty, Volume 1 . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/paulding.14.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/paulding.14',
#   '__id': 555864},
#  {'author': 'Taylor, Bayard, 1825-1878',
#   'title': 'The Story of Kennett. (1866): a machine&hyphen;readable transcript',
#   'year': '1866',
#   'idref': 'Z100787220',
#   'pub': 'G. P. Putnam',
#   'type': 'BOOK',
#   'name': '<doc><dochead><comhd1><idref>Z100787220</idref><collection>1 2</collection><mainhead>The Story of Kennett.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/taylorba.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/taylorba.05',
#   '__id': 555865},
#  {'author': 'Hall, James, 1793-1868',
#   'title': 'The Wilderness and the War Path . . . (1846)',
#   'year': '1846',
#   'idref': 'Z100007472',
#   'pub': 'Wiley &amp; Putnam',
#   'type': 'BOOK',
#   'name': '<mainhead>The Wilderness and the War Path . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/halljame.05.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/halljame.05',
#   '__id': 555866},
#  {'author': 'Aldrich, Thomas Bailey, 1836-1907',
#   'title': "Daisy's Necklace: and What Came of It. (A Literary Episode.) (1857)",
#   'year': '1857',
#   'idref': 'Z100719880',
#   'pub': 'Derby &amp; Jackson',
#   'type': 'BOOK',
#   'name': "<mainhead>Daisy's Necklace: and What Came of It. (A Literary Episode.)</mainhead>",
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/aldricht.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/aldricht.01',
#   '__id': 555867},
#  {'author': 'Paulding, James Kirke, 1778-1860',
#   'title': 'The New Mirror for Travellers, and Guide to the Springs. By an Amateur . . . (1828)',
#   'year': '1828',
#   'idref': 'Z100016227',
#   'pub': 'G. &amp; C. Carvill',
#   'type': 'BOOK',
#   'name': '<mainhead>The New Mirror for Travellers, and Guide to the Springs. By an Amateur . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/paulding.13.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/paulding.13',
#   '__id': 555868},
#  {'author': 'Child, Lydia Maria Francis, 1802-1880',
#   'title': 'Philothea (1836)',
#   'year': '1836',
#   'idref': 'Z100003476',
#   'pub': 'Otis, Broaders &amp; Co.',
#   'type': 'BOOK',
#   'name': '<mainhead>Philothea</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/childlyd.09.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/childlyd.09',
#   '__id': 555869},
#  {'author': 'Fay, Theodore S. (Theodore Sedgwick), 1807-1898',
#   'title': 'The Countess Ida: A Tale of Berlin . . .  Volume 1 (1840)',
#   'year': '1840',
#   'idref': 'Z100005978',
#   'pub': 'Harper &amp; Brothers',
#   'type': 'BOOK',
#   'name': '<mainhead>The Countess Ida: A Tale of Berlin . . .  Volume 1</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/faytheod.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/faytheod.03',
#   '__id': 555870},
#  {'author': 'Rowson, Mrs., 1762-1824',
#   'title': "Charlotte's Daughter; or, The Three Orphans. A Sequel to Charlotte Temple (1828)",
#   'year': '1828',
#   'idref': 'Z100016905',
#   'pub': 'Richardson &amp; Lord',
#   'type': 'BOOK',
#   'name': "<mainhead>Charlotte's Daughter; or, The Three Orphans. A Sequel to Charlotte Temple</mainhead>",
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/rowsonmr.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/rowsonmr.01',
#   '__id': 555871},
#  {'author': 'Twain, Mark, 1835-1910',
#   'title': 'The Celebrated Jumping Frog of Calaveras County, and Other Sketches. (1867)',
#   'year': '1867',
#   'idref': 'Z100721533',
#   'pub': 'C.H. Webb',
#   'type': 'BOOK',
#   'name': '<mainhead>The Celebrated Jumping Frog of Calaveras County, and Other Sketches.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/twainmar.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/twainmar.01',
#   '__id': 555872},
#  {'author': 'Irving, Washington, 1783-1859',
#   'title': 'Letters of Jonathan Oldstyle, Gent. [pseud (1824)',
#   'year': '1824',
#   'idref': 'Z100011165',
#   'pub': 'William H, Clayton',
#   'type': 'BOOK',
#   'name': '<mainhead>Letters of Jonathan Oldstyle, Gent. [pseud</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/irvingwa.18.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/irvingwa.18',
#   '__id': 555873},
#  {'author': 'Bagby, George William, 1828-1883',
#   'title': 'What I did with My Fifty Millions. By Moses Adams. (pseud.) (1874)',
#   'year': '1874',
#   'idref': 'Z100720336',
#   'pub': 'J.B. Lippincott &amp; Co.',
#   'type': 'BOOK',
#   'name': '<mainhead>What I did with My Fifty Millions. By Moses Adams. (pseud.)</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/bagbygeo.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/bagbygeo.01',
#   '__id': 555874},
#  {'author': 'Thomas, Frederick W. (Frederick William), 1806-1866',
#   'title': 'East and West, Volume 2 (1836)',
#   'year': '1836',
#   'idref': 'Z100020728',
#   'pub': 'Carey, Lea, &amp; Blanchard',
#   'type': 'BOOK',
#   'name': '<mainhead>East and West, Volume 2</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/thomasfr.04.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/thomasfr.04',
#   '__id': 555875},
#  {'author': 'Sedgwick, Catharine Maria, 1789-1867',
#   'title': 'Live and Let Live; or, Domestic Service Illustrated (1837)',
#   'year': '1837',
#   'idref': 'Z100018025',
#   'pub': 'Harper &amp; Brothers',
#   'type': 'BOOK',
#   'name': '<mainhead>Live and Let Live; or, Domestic Service Illustrated</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/sedgwick.12.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/sedgwick.12',
#   '__id': 555876},
#  {'author': 'Bennett, Emerson, 1822-1905',
#   'title': 'Viola; or, Adventures in the Far South-west. (1852)',
#   'year': '1852',
#   'idref': 'Z100720706',
#   'pub': 'T.B. Peterson',
#   'type': 'BOOK',
#   'name': '<mainhead>Viola; or, Adventures in the Far South-west.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/bennette.15.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/bennette.15',
#   '__id': 555877},
#  {'author': 'Cooper, James Fenimore, 1789-1851',
#   'title': 'The Pathfinder; or, The Inland Sea, Vol.II (1840)',
#   'year': '1840',
#   'idref': 'Z100634444',
#   'pub': 'Lea and Blanchard',
#   'type': 'BOOK',
#   'name': '<mainhead>The Pathfinder; or, The Inland Sea, Vol.II</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/cooperja.31.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/cooperja.31',
#   '__id': 555878},
#  {'author': 'Child, Lydia Maria Francis, 1802-1880',
#   'title': 'The Church in the Wilderness, from The Legendary, N. P. Willis, ed. . . . (1828)',
#   'year': '1828',
#   'idref': 'Z100003285',
#   'pub': 'Samuel G. Goodrich',
#   'type': 'BOOK',
#   'name': '<mainhead>The Church in the Wilderness, from The Legendary, N. P. Willis, ed. . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/childlyd.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/childlyd.03',
#   '__id': 555879},
#  {'author': 'Cooper, James Fenimore, 1789-1851',
#   'title': 'The Sea Lions; or, The Lost Sealers Volume 2 (1849)',
#   'year': '1849',
#   'idref': 'Z100634856',
#   'pub': 'Stringer &amp; Townsend',
#   'type': 'BOOK',
#   'name': '<mainhead>The Sea Lions; or, The Lost Sealers Volume 2</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/cooperja.45.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/cooperja.45',
#   '__id': 555880},
#  {'author': 'Rowson, Mrs., 1762-1824',
#   'title': 'Reuben and Rachel; or, Tales of Old Times, Volume 2 . . . (1798)',
#   'year': '1798',
#   'idref': 'Z100017233',
#   'pub': 'Manning &amp; Lording, for David West',
#   'type': 'BOOK',
#   'name': '<mainhead>Reuben and Rachel; or, Tales of Old Times, Volume 2 . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/rowsonmr.11.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/rowsonmr.11',
#   '__id': 555881},
#  {'author': 'Ward, Elizabeth Stuart Phelps, 1844-1911',
#   'title': 'Men, Women, and Ghosts. (1869)',
#   'year': '1869',
#   'idref': 'Z100725717',
#   'pub': 'Fields, Osgood &amp;Co.',
#   'type': 'BOOK',
#   'name': '<mainhead>Men, Women, and Ghosts.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/wardeliz.03.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/wardeliz.03',
#   '__id': 555882},
#  {'author': 'Simms, William Gilmore, 1806-1870',
#   'title': 'The Kinsmen; or, The Black Riders of Congaree, Volume 2 (1841)',
#   'year': '1841',
#   'idref': 'Z100019170',
#   'pub': 'Lea &amp; Blanchard',
#   'type': 'BOOK',
#   'name': '<mainhead>The Kinsmen; or, The Black Riders of Congaree, Volume 2</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/simmswil.23.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/simmswil.23',
#   '__id': 555883},
#  {'author': 'Paulding, James Kirke, 1778-1860',
#   'title': "Jonathan's Visit to the Celestial Empire: from The Atlantic Club-Book (1834)",
#   'year': '1834',
#   'idref': 'Z100016108',
#   'pub': 'Harper &amp; Brothers',
#   'type': 'BOOK',
#   'name': "<mainhead>Jonathan's Visit to the Celestial Empire: from The Atlantic Club-Book</mainhead>",
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/paulding.08.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/paulding.08',
#   '__id': 555884},
#  {'author': 'Trowbridge, J. T. (John Townsend), 1827-1916',
#   'title': 'Coupon Bonds, and Other Stories. (1873): a machine&hyphen;readable transcript',
#   'year': '1873',
#   'idref': 'Z100787572',
#   'pub': 'James R. Osgood and Company',
#   'type': 'BOOK',
#   'name': '<doc><dochead><comhd1><idref>Z100787572</idref><collection>1 2</collection><mainhead>Coupon Bonds, and Other Stories.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/trowbrid.02.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/trowbrid.02',
#   '__id': 555885},
#  {'author': 'Brown, Charles Brockden, 1771-1810',
#   'title': 'Jane Talbot . . . (1801)',
#   'year': '1801',
#   'idref': 'Z100002626',
#   'pub': 'John Conrad &amp; Co.',
#   'type': 'BOOK',
#   'name': '<mainhead>Jane Talbot . . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/browncha.08.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/browncha.08',
#   '__id': 555886},
#  {'author': 'Alcott, Louisa May, 1832-1888',
#   'title': 'Hospital Sketches and Camp and Fireside Stories. (1869)',
#   'year': '1869',
#   'idref': 'Z100719748',
#   'pub': 'Roberts Brothers',
#   'type': 'BOOK',
#   'name': '<mainhead>Hospital Sketches and Camp and Fireside Stories.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/alcottlo.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/alcottlo.01',
#   '__id': 555887},
#  {'author': 'Jacobs, Harriet A. (Harriet Ann), 1813-1897',
#   'title': 'Incidents in the Life of A Slave Girl.  Written by Herself. (1861)',
#   'year': '1861',
#   'idref': 'Z100725083',
#   'pub': 'Published for the Author',
#   'type': 'BOOK',
#   'name': '<mainhead>Incidents in the Life of A Slave Girl.  Written by Herself.</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/jacobsha.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/jacobsha.01',
#   '__id': 555888},
#  {'author': 'Sedgwick, Catharine Maria, 1789-1867',
#   'title': 'The Linwoods, volume 1 (1835)',
#   'year': '1835',
#   'idref': 'Z100017920',
#   'pub': 'Harper &amp; Brothers',
#   'type': 'BOOK',
#   'name': '<mainhead>The Linwoods, volume 1</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/sedgwick.10.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/sedgwick.10',
#   '__id': 555889},
#  {'author': 'Neal, John, 1793-1876',
#   'title': 'Authorship: A Tale . . (1830)',
#   'year': '1830',
#   'idref': 'Z100015245',
#   'pub': 'Gray and Bowen',
#   'type': 'BOOK',
#   'name': '<mainhead>Authorship: A Tale . .</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/nealjohn.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/nealjohn.01',
#   '__id': 555890},
#  {'author': 'Derby, George Horatio, 1823-1861',
#   'title': 'Phoenixiana; or, Sketches and Burlesques. By John Phoenix. (pseud.) (1856)',
#   'year': '1856',
#   'idref': 'Z100724387',
#   'pub': 'D. Appleton and Company',
#   'type': 'BOOK',
#   'name': '<mainhead>Phoenixiana; or, Sketches and Burlesques. By John Phoenix. (pseud.)</mainhead>',
#   'nation': 'American',
#   'medium': 'Fiction',
#   'subcorpus': 'Early_American_Fiction',
#   'fn_raw': 'Early_American_Fiction/derbygeo.01.new',
#   '_type': 'Text',
#   '_corpus': 'chadwyck',
#   'id': '_chadwyck/Early_American_Fiction/derbygeo.01',
#   '__id': 555891},
#  ...]

# %%
LLTK.sync()
# Out:
# [LLTK] Syncing across corpora:   0%|          | 0/19 [00:00<?, ?it/s]
# [TedJDH] Syncing texts to db:   0%|          | 0/3778 [00:00<?, ?it/s]
#   0%|          | 0/3778 [00:00<?, ?it/s]
# [EEBO_TCP] Syncing texts to db:   0%|          | 0/56351 [00:00<?, ?it/s]
#   0%|          | 0/56351 [00:00<?, ?it/s]
# [ECCO_TCP] Syncing texts to db:   0%|          | 0/3101 [00:00<?, ?it/s]
#   0%|          | 0/3101 [00:00<?, ?it/s]
# [RavenGarside] Syncing texts to db: 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# [EvansTCP] Syncing texts to db:   0%|          | 0/5012 [00:00<?, ?it/s]
#   0%|          | 0/5012 [00:00<?, ?it/s]
# [Spectator] Syncing texts to db:   0%|          | 0/842 [00:00<?, ?it/s]
#   0%|          | 0/842 [00:00<?, ?it/s]
# [GildedAge] Syncing texts to db:   0%|          | 0/334 [00:00<?, ?it/s]
#   0%|          | 0/334 [00:00<?, ?it/s]
# [ESTC] Syncing texts to db:   0%|          | 0/481711 [00:00<?, ?it/s]
#   0%|          | 0/481711 [00:00<?, ?it/s]
# [MarkMark] Syncing texts to db:   0%|          | 0/355 [00:00<?, ?it/s]
#   0%|          | 0/355 [00:00<?, ?it/s]
# [TxtLab] Syncing texts to db:   0%|          | 0/450 [00:00<?, ?it/s]
#   0%|          | 0/450 [00:00<?, ?it/s]
# [SemanticCohort] Syncing texts to db:   0%|          | 0/2958 [00:00<?, ?it/s]
#   0%|          | 0/2958 [00:00<?, ?it/s]
# [Chadwyck] Syncing texts to db:   0%|          | 0/1337 [00:00<?, ?it/s]
#   0%|          | 0/1337 [00:00<?, ?it/s]
# [DTA] Syncing texts to db:   0%|          | 0/3295 [00:00<?, ?it/s]
#   0%|          | 0/3295 [00:00<?, ?it/s]
# [CLMET] Syncing texts to db:   0%|          | 0/333 [00:00<?, ?it/s]
#   0%|          | 0/333 [00:00<?, ?it/s]
# [CanonFiction] Syncing texts to db:   0%|          | 0/1805 [00:00<?, ?it/s]
#   0%|          | 0/1805 [00:00<?, ?it/s]
# [ECCO] Syncing texts to db:   0%|          | 0/154924 [00:00<?, ?it/s]
#   0%|          | 0/154924 [00:00<?, ?it/s]
# [LitLab] Syncing texts to db:   0%|          | 0/5411 [00:00<?, ?it/s]
#   0%|          | 0/5411 [00:00<?, ?it/s]
# [DialNarr] Syncing texts to db:   0%|          | 0/1918 [00:00<?, ?it/s]
#   0%|          | 0/1918 [00:00<?, ?it/s]
# [Chicago] Syncing texts to db:   0%|          | 0/9089 [00:00<?, ?it/s]
#   0%|          | 0/9089 [00:00<?, ?it/s]

# %%
# C.sync()

# %%
len(mdb.db.all())

# %%
mdb.set('hello',{'a':1, 'c':5})

# %%
mdb.get('hello')

# %%
list(mdb.get(a={'$gt':0}))

# %%
list(mdb.get(_corpus='chadwyck'))

# %%
for d in Corpus('chadwyck').init_meta(): pass
d
# Out:
# ('Early_English_Prose_Fiction/ee12010.02',
#  {'author': 'Belon, P. (Peter)',
#   'idref': 'Z200025432',
#   'medium': 'Fiction',
#   'name': 'Title Page',
#   'nation': 'British',
#   'pub': 'Printed for the Author, & are sold by A. Banks and C. Harper [etc.]',
#   'subcorpus': 'Early_English_Prose_Fiction',
#   'title': 'A Relation of the Country of Jansenia (1668)',
#   'type': 'BOOK',
#   'year': '1668'})

# %%
ld
