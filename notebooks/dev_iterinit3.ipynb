# %%
import sys; sys.path.insert(0,'../../yapmap')
import sys; sys.path.insert(0,'..')
from lltk import *

# %%
with log:
    C=Corpus('markmark')
    t=C.t
t.metadata(remote=True)
# Out:
# [15:42:51] lltk.corpus.corpus.Corpus( <- id = markmark )
# [15:42:51] lltk.corpus.utils.load_corpus( <- id = markmark )
# [15:42:51] lltk.corpus.utils.load_corpus( Importing corpus class "MarkMark" from /Users/ryan/github/lltk/lltk/corpus/markmark/markmark.py )
# [15:42:51] lltk.corpus.corpus.__init__( MarkMark(markmark) )
# [15:42:51] lltk.corpus.utils.load_corpus( -> MarkMarkCorpus(markmark) )
# [15:42:51] lltk.corpus.corpus.Corpus( -> MarkMarkCorpus(markmark) )
# [15:42:51] lltk.corpus.corpus.textd( ... )
# [15:42:51] lltk.corpus.corpus.init( ... )
# [15:42:51] lltk.corpus.corpus.init( MarkMarkCorpus(markmark) )
# [markmark] initializing texts from database:   0%|          | 0/355 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2     C=Corpus('markmark')
#       3     t=C.t
# ----> 4 t.metadata(remote=True)
#
# ...

# %%
addr=t.meta.get('id__hathi')
GDB().get('_hathi/'+addr)
# Out:
# {'_corpus': 'hathi',
#  '_addr': '_hathi/htrn/001187397',
#  'id': '_hathi/htrn/001187397',
#  'htid': 'mdp.39015005670099',
#  'lccn': '67009604',
#  'num_vols': 1,
#  'oclc': '290469',
#  'publishDate': '1967',
#  'recordURL': 'https://catalog.hathitrust.org/Record/001187397',
#  'title': 'Cane',
#  'year': 1967}

# %%
addr=t.meta.get('id__wikidata')
GDB().get('_wikidata/'+addr)
# Out:
# {'_corpus': 'wikidata',
#  '_addr': '_wikidata/Q3655399',
#  'id': '_wikidata/Q3655399',
#  'author|P50': 'Jean Toomer|Q1277467',
#  'copyright_status|P6216': 'public domain|Q19652',
#  'encyclopaedia_britannica_online_id|P1417': 'topic/Cane-by-Toomer',
#  'form_of_creative_work|P7937': 'novel|Q8261',
#  'freebase_id|P646': '/m/03d0lhg',
#  'genre|P136': 'novel|Q8261',
#  'instance_of|P31': 'written work|Q47461344',
#  'label': 'Cane',
#  'language_of_work_or_name|P407': 'English|Q1860',
#  'narrative_location|P840': 'Chicago|Q1297',
#  'project_gutenberg_ebook_id|P2034': '60093',
#  'publication_date|P577': '+1923-00-00T00:00:00Z',
#  'what': 'written work'}

# %%
txt=gethtml('https://www.worldcat.org/search?q=ti%3AUlysses+au%3AJoyce&fq=x0%3Abook+%3E+ln%3Aeng&qt=advanced&dblist=638')

# %%
gethtml('')

# %%
C.metadata(remote=True)
# Out:
# [MarkMark] Iterating texts:   0%|          | 0/355 [00:00<?, ?it/s]
# Note: Wikidata item Q5530982 missing 'instance of' (P31)
# Note: Wikidata item Q5913648 missing 'instance of' (P31)
# Note: Wikidata item Q13404967 missing 'instance of' (P31)
#                                                      _corpus  \
# id
# Achebe,_Chinua.Things_Fall_Apart                    markmark
# Acker,_Kathy.In_Memoriam_to_Identity                markmark
# Adams,_Douglas.The_Hitchhikers_Guide_to_the_Galaxy  markmark
# Adams,_Richard.Watership_Down                       markmark
# Albom,_Mitch.For_One_More_Day                       markmark
# ...                                                      ...
# de_Lint,_Charles.Trader                             markmark
# de_Lint,_Charles.Yarrow                             markmark
# du_Maurier,_Daphne.Rebecca                          markmark
# du_Maurier,_Daphne.The_Kings_General                markmark
# ...
