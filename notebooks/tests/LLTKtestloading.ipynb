# %%
# grab the lltk in this repo
import sys
sys.path.insert(0,'../..')
import lltk
lltk.__file__
# Out:
# '../../lltk/__init__.py'

# %%
# lltk.show()

# %%
# corpus = lltk.load('TxtLab')

# %%
# corpus.meta

# %%
# corpus.mfw_df()

# %%
corpus2 = lltk.load('Chicago')

# %%
corpus2.meta
# Out:
#                             author  \
# id
# 00000001              Adams, Henry
# 00000003    Aldrich, Thomas Bailey
# 00000013  Burnett, Frances Hodgson
# 00000015  Cable, George Washington
# 00000021        Douglas, Amanda M.
# ...                            ...
# 00026229            Weis, Margaret
# 00026230                Wells, Ken
# 00026231             Wilhelm, Kate
# 00026232             Woods, Stuart
# 00026233          Youngblood, Shay
#
#                                                   title  year alt_first  \
# id
# 00000001                                      Democracy  1880
# 00000003                         The Stillwater tragedy  1880
# 00000013                                      Louisiana  1880
# 00000015                               The Grandissimes  1880
# 00000021  Hope Mills: or: Between friend and sweetheart  1880
# ...                                                 ...   ...       ...
# 00026229                        Dragons of winter night  2000
# ...

# %%
corpus2.mfw_df()
# Out:
# Computing most frequent words across all texts [x7]: 100%|██████████| 9089/9089 [01:20<00:00, 113.36it/s]
#                count           fpm   rank  ranks_avg  pos pos0
# word
# the         47506928  53269.360039      1          1   at    a
# and         24267355  27210.904285      2          2   cc    c
# to          22687032  25438.893372      3          3   to    t
# a           19832007  22237.563355      4          4   at    a
# of          19260428  21596.653727      5          5   ii    i
# ...              ...           ...    ...        ...  ...  ...
# chatty          1135      1.272672  24994      25000   jj    j
# economical      1135      1.272672  24997      25005   jj    j
# grapevine       1135      1.272672  24998      24997  nn1    n
# crafts          1135      1.272672  24999      24999  nn2    n
# taillights      1135      1.272672  25000      25006  nn2    n
#
# [19791 rows x 6 columns]
