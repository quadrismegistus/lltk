# %% [markdown]
# # W2V

# %%
import sys; sys.path.insert(0,'..')
from lltk.imports import *

# %%
C = Corpus('markmark')
C.metadata()
# Out:
#                                                                                       _addr  \
# id
# Caldwell_Erskine.Tobacco_Road                       _markmark/Caldwell_Erskine.Tobacco_Road
# Sinclair_Upton.The_Jungle                               _markmark/Sinclair_Upton.The_Jungle
# Hemingway_Ernest.In_Our_Time                         _markmark/Hemingway_Ernest.In_Our_Time
# Hemingway_Ernest.A_Farewell_to_Arms           _markmark/Hemingway_Ernest.A_Farewell_to_Arms
# Hemingway_Ernest.For_Whom_the_Bell_Tolls  _markmark/Hemingway_Ernest.For_Whom_the_Bell_T...
# ...                                                                                     ...
# Sukenick_Ronald.Up                                             _markmark/Sukenick_Ronald.Up
# Bennett_Arnold.The_Old_Wives_Tale               _markmark/Bennett_Arnold.The_Old_Wives_Tale
# Robbins_Tom.Skinny_Legs_and_All                   _markmark/Robbins_Tom.Skinny_Legs_and_All
# ...

# %%
C.word2vec()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/notebooks/test_w2v.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/notebooks/test_w2v.ipynb#ch0000010?line=0'>1</a> C.word2vec()
#
# File ~/github/lltk/notebooks/../lltk/corpus/corpus.py:1151, in BaseCorpus.word2vec(self, skipgram_n, name, skipgram_fn)
#    <a href='file:///Users/ryan/github/lltk/notebooks/../lltk/corpus/corpus.py?line=1148'>1149</a> def word2vec(self,skipgram_n=10,name=None,skipgram_fn=None):
#    <a href='file:///Users/ryan/github/lltk/notebooks/../lltk/corpus/corpus.py?line=1149'>1150</a>     if not name: name=self.name
# -> <a href='file:///Users/ryan/github/lltk/notebooks/../lltk/corpus/corpus.py?line=1150'>1151</a>     from lltk.model.word2vec import Word2Vec
# ...

# %%
C.wikidata.meta
# Out:
# [21:35:47] lltk.corpus.corpus.Corpus():1382: Corpus loaded: [Wikidata](wikidata)
# [21:35:47] lltk.corpus.corpus.init_meta_files():279: Initializing from files: [Wikidata](wikidata)
# Finding metadata:   0%|          | 0/725 [00:00<?, ?it/s]

# %%
C.wikidata.meta
# Out:
# Finding metadata:   0%|          | 0/293 [00:00<?, ?it/s]
#                  instance_of|P31                        author|P50  \
# id
# Q1045464  literary work|Q7725634             Edith Wharton|Q276032
# Q1195793  literary work|Q7725634  William Somerset Maugham|Q134942
# Q4086674  written work|Q47461344      William S. Burroughs|Q188176
# Q4763360  written work|Q47461344           Wallace Stegner|Q203460
# Q265954   literary work|Q7725634              Kurt Vonnegut|Q49074
# ...                          ...                               ...
# Q7752560  literary work|Q7725634              Walker Percy|Q176909
# Q5877236  written work|Q47461344          Samuel R. Delany|Q438164
# Q2384854  written work|Q47461344            William Gibson|Q188987
# Q929821   written work|Q47461344        Robert A. Heinlein|Q123078
# Q7775717  literary work|Q7725634           Terri Windling|Q3518754
#
#                                    narrative_location|P840  \
# id
# ...

# %%
C.metadata(progress=True)
# Out:
#                                                                                                 _addr  \
# id
# DE_1771_La Roche,Sophievon_GeschichtedesFräule...  _txtlab/DE_1771_La_RocheSophievon_Geschichtede...
# DE_1774_Goethe,Johann_DieLeidendesjungenWerther...  _txtlab/DE_1774_GoetheJohann_DieLeidendesjunge...
# DE_1774_Wieland,ChristophMartin_GeschichtederAb...  _txtlab/DE_1774_WielandChristophMartin_Geschic...
# DE_1776_Nicolai,Friedrich_SebaldusNothanker_Novel   _txtlab/DE_1776_NicolaiFriedrich_SebaldusNotha...
# DE_1779_Campe,Joachim_Robinson_Novel                      _txtlab/DE_1779_CampeJoachim_Robinson_Novel
# ...                                                                                               ...
# FR_1926_Giraudoux,Jean_Bella_Novel                          _txtlab/FR_1926_GiraudouxJean_Bella_Novel
# FR_1926_Ramuz,CharlesFerdinand_GrandePeurDansla...  _txtlab/FR_1926_RamuzCharlesFerdinand_GrandePe...
# ...
