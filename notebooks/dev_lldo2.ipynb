# %%
import sys; sys.path.insert(0,'..')
import lltk
from lltk.imports import *
# lltk.log.on()
# Out:
# (18:13:10.748) [LLTK] booting
# (18:13:11.514) [LLTK] --------------------------------------------------
# (18:13:11.514) [LLTK] ready

# %%
tl1=lltk.search(corpus='chicago')
tl1
# Out:
# ChicagoCorpus(chicago)

# %%
tl1.init()
# Out:
# (18:13:13.985) [LLTK] loading csv

# %%
log.on()
log.verbose=2
tl1.data_all
# Out:
# (18:09:11.589) [LLTK] converting to text...
# (18:09:13.824) [LLTK] done
# [Adams, Democracy (1880) [_chicago/00000001],
#  Aldrich, The Stillwater Tragedy (1880) [_chicago/00000003],
#  Burnett, Louisiana (1880) [_chicago/00000013],
#  Cable, The Grandissimes (1880) [_chicago/00000015],
#  Douglas, Hope Mills (1880) [_chicago/00000021],
#  Ewell, The Harvest Of Years (1880) [_chicago/00000022],
#  James, Confidence (1880) [_chicago/00000037],
#  James, A Bundle Of Letters (1880) [_chicago/00000038],
#  James, The Diary Of A Man Of Fifty (1880) [_chicago/00000039],
#  Pinkerton, Bucholz And The Detectives (1880) [_chicago/00000048],
#  Roe, A Day Of Fate (1880) [_chicago/00000050],
#  Warner, The End Of A Coil (1880) [_chicago/00000052],
#  Woolson, Rodman The Keeper (1880) [_chicago/00000053],
#  Cable, Madame Delphine (1881) [_chicago/00000062],
#  Green, The Sword Of Damocles (1881) [_chicago/00000075],
#  Howells, A Modern Instance (1881) [_chicago/00000080],
# ...

# %%
# %%timeit
[Text(id,**d) for id,d in tl1._data_all]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/ryan/github/lltk/notebooks/dev_lldo2.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ryan/github/lltk/notebooks/dev_lldo2.ipynb#ch0000009?line=0'>1</a> get_ipython().run_cell_magic('timeit', '', '[Text(id,**d) for id,d in tl1._data_all]\n')
#
# File ~/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2347, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2344'>2345</a> with self.builtin_trap:
#    <a href='file:///Users/ryan/miniforge3/lib/python3.9/site-packages/IPython/core/interactiveshell.py?line=2345'>2346</a>     args = (magic_arg_s, cell)
# ...

# %%
tl2=lltk.search(corpus='chicago')

# %%
tl1
# Out:
# TextList([(_markmark/Updike,_John.Rabbit,_Run)
#           (_markmark/Heinlein,_Robert.Citizen_of_the_Galaxy)
#           (_markmark/Holdstock,_Robert.Mythago_Wood)
#           (_markmark/Heinlein,_Robert.Stranger_in_a_Strange_Land)
#           (_markmark/Albom,_Mitch.For_One_More_Day)
#           (_markmark/Heinlein,_Robert.The_Moon_is_a_Harsh_Mistress)
#           (_markmark/Powell,_Anthony.A_Question_of_Upbringing)
#           (_markmark/Joyce,_James.A_Portrait_of_the_Artist_as_a_Young_Man)
#           (_markmark/Shute,_Nevil.On_the_Beach)
#           (_markmark/Barth,_John.The_Sot-Weed_Factor)
#           (_markmark/Hemingway,_Ernest.In_Our_Time)
#           (_markmark/Waugh,_Evelyn.A_Handful_of_Dust)
#           (_markmark/le_Carré,_John.The_Spy_Who_Came_In_from_the_Cold)
#           (_markmark/de_Lint,_Charles.Someplace_to_Be_Flying)
#           (_markmark/Beckett,_Samuel.Malone_Dies)
#           (_markmark/Tarkington,_Booth.Seventeen)
# ...

# %%
tl2
# Out:
# [TextList] (loading...)
