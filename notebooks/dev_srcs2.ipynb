# %%
import sys; sys.path.insert(0,'../../yapmap')
import sys; sys.path.insert(0,'..')
from lltk import *

# %%
C=Corpus('Hathi')
t = Text(title="Betsy Thoughtless", author="Haywood")

# %%
with log: ht = C.text(t)
ht
# Out:
# [22:08:28] lltk.corpus.corpus.text( <- id = BaseText(_tmp/author:Haywood/title:Betsy_Thoughtless), corpus = HathiCorpus(hathi) )
# [22:08:28] hathi.get_text_id( <- id = BaseText(_tmp/author:Haywood/title:Betsy_Thoughtless), kwargs = ['_new'] )
# [22:08:28] hathi.query_for_ids( <- BaseText(_tmp/author:Haywood/title:Betsy_Thoughtless) )
# [22:08:28] hathi.query_for_ids( found result on db (6 records) )
# [22:08:28] hathi.get_text_id( -> htrn/008663329 )
# [22:08:28] lltk.corpus.corpus.text( id set to: htrn/008663329 )
# [22:08:28] lltk.corpus.corpus.init_text( <- id = htrn/008663329, corpus = HathiCorpus(hathi) )
# [22:08:28] lltk.text.text.__init__( <- id = htrn/008663329, corpus = HathiCorpus(hathi) )
# [22:08:28] lltk.text.text.__init__( TextHathi(id = htrn/008663329, corpus = HathiCorpus(hathi)) )
# [22:08:28] lltk.corpus.corpus.init_text( -> TextHathi(_hathi/htrn/008663329) )
# [22:08:28] lltk.text.text.cache( TextHathiRecord(_hathi/htrn/008663329) )
# ...

# %%
ht.sources
# Out:
# [TextHathi(_hathi/T00003),
#  TextHathi(_hathi/T00005),
#  TextHathi(_hathi/T00007),
#  TextHathi(_hathi/T00002),
#  TextHathi(_hathi/T00004),
#  TextHathi(_hathi/T00006)]

# %%
t3=Text(title="Emma",author="Austen")
t3.qstr
# Out:
# 'Emma Austen'

# %%
with log: ht3 = C.text(t3)
ht3
# Out:
# [22:04:12] lltk.corpus.corpus.text( <- id = BaseText(_tmp/author:Austen/title:Emma), corpus = HathiCorpus(hathi) )
# [22:04:12] hathi.query_for_ids( <- BaseText(_tmp/author:Austen/title:Emma) )
# [22:04:13] hathi.query_for_ids( found result on website (61 records) )
# ...

# %%
with log: x=ht3.metadata(remote=True)
x
# Out:
# [22:04:13] hathi.query( ('recordnumber', '100073189') )
# [22:04:13] lltk.text.text.Text( <- id = _hathi/htid/dul1.ark:/13960/t8x93fx03 )
# [22:04:13] lltk.text.text.Text( <- addr = _hathi/htid/dul1.ark:/13960/t8x93fx03 )
# [22:04:13] lltk.corpus.corpus.Corpus( <- id = hathi )
# [22:04:13] lltk.corpus.corpus.Corpus( -> HathiCorpus(hathi) )
# [22:04:13] lltk.corpus.corpus.text( <- id = htid/dul1.ark:/13960/t8x93fx03, corpus = HathiCorpus(hathi) )
# [22:04:13] hathi.query_for_ids( <- htid/dul1.ark:/13960/t8x93fx03 )
# [22:04:13] lltk.text.text.Text( <- id = htid/dul1.ark:/13960/t8x93fx03 )
# [22:04:13] lltk.text.text.Text( <- addr = _tmp/htid/dul1.ark:/13960/t8x93fx03 )
# [22:04:13] lltk.corpus.corpus.Corpus( <- id = tmp )
# [22:04:13] lltk.corpus.corpus.Corpus( -> BaseCorpus(tmp) )
# [22:04:13] lltk.corpus.corpus.text( <- id = htid/dul1.ark:/13960/t8x93fx03, corpus = BaseCorpus(tmp) )
# ...
